# %% [markdown]
# # SQL Project Analysis
# ## Redfin Data Analyst Intern

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql://~USER~:~PASSWORD~@~AWS_HOST~/~DATABASE_NAME~

# %% [markdown]
# ## Exploratory Queries

# %% [markdown]
# ### 1.
# #### Many measurements for smaller counties in all states turn up NULL results since there is either no data being registered from those counties, or Redfin does not collect from them since they are not active housing markets.
#
# #### Purpose: This query sorts out all of the NULL values for total_homes_sold, which I have determined to be one of the main measurements I will be looking for in the property data that is generally indicative of whether or not other measurements have been collected as well.Additionally, this query gives a brief snapshot of some of the most active housing markets in terms of homes sold and active listings. It also provides the median sale price for each.
#
# #### Estimated Run Time: ~1 second

# %%
# %%sql
# SELECT
#     region_name,
#     SUM(total_homes_sold) AS total_homes_sold,
#     FORMAT(AVG(median_sale_price), 0) AS avg_median_sale_price,
#     FORMAT(AVG(total_active_listings), 0) AS avg_total_active_listings
# FROM housing_data
# WHERE total_homes_sold IS NOT NULL
# GROUP BY region_name
# ORDER BY total_homes_sold DESC, median_sale_price;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 235 rows affected.
# [('Houston, TX metro area', 6312067.0, '243,525', '152,545'),
#  ('Los Angeles County, CA', 4907011.0, '633,365', '102,865'),
#  ('Los Angeles, CA metro area', 4907011.0, '633,365', '102,865'),
#  ('Dallas, TX metro area', 4761026.0, '293,357', '94,801'),
#  ('New York, NY metro area', 4674078.0, '547,929', '208,524'),
#  ('Riverside, CA metro area', 4097739.0, '378,499', '90,244'),
#  ('Harris County, TX', 3647624.0, '227,531', '86,317'),
#  ('San Diego, CA metro area', 2541703.0, '585,497', '38,203'),
#  ('San Diego County, CA', 2541703.0, '585,497', '38,203'),
#  ('Austin, TX metro area', 2538921.0, '320,710', '43,178'),
#  ('Riverside County, CA', 2484347.0, '391,391', '54,991'),
#  ('Fort Worth, TX metro area', 2442282.0, '240,544', '41,147'),
#  ('San Antonio, TX metro area', 2364552.0, '230,022', '51,207'),
#  ('Sacramento, CA metro area', 2279331.0, '410,968', '30,603'),
#  ('Nassau County, NY metro area', 2131589.0, '453,815', '60,716'),
#  ('Anaheim, CA metro area', 2125000.0, '720,726', '44,785'),
#  ('Orange County, CA', 2125000.0, '720,726', '44,785'),
#  ('Tarrant County, TX', 1981203.0, '238,338', '31,147'),
#  ('Oakland, CA metro area', 1920825.0, '735,518', '19,783'),
#  ('Dallas County, TX', 1777304.0, '250,575', '35,624'),
#  ('Bexar County, TX', 1770757.0, '216,889', '36,438'),
#  ('San Bernardino County, CA', 1613392.0, '355,104', '35,253'),
#  ('Sacramento County, CA', 1366115.0, '368,832', '15,525'),
#  ('Travis County, TX', 1330461.0, '369,339', '22,203'),
#  ('Suffolk County, NY', 1203417.0, '395,320', '33,214'),
#  ('Collin County, TX', 1201594.0, '338,508', '24,844'),
#  ('Denton County, TX', 1108998.0, '314,421', '20,785'),
#  ('San Jose, CA metro area', 1031733.0, '1,113,368', '11,968'),
#  ('Santa Clara County, CA', 988149.0, '1,141,071', '11,081'),
#  ('Contra Costa County, CA', 965578.0, '627,968', '10,164'),
#  ('Alameda County, CA', 955247.0, '831,315', '9,619'),
#  ('Nassau County, NY', 928172.0, '530,249', '27,501'),
#  ('Fort Bend County, TX', 903669.0, '283,036', '22,088'),
#  ('Rochester, NY metro area', 872004.0, '147,606', '12,807'),
#  ('Williamson County, TX', 836401.0, '289,350', '13,510'),
#  ('Buffalo, NY metro area', 831281.0, '153,052', '12,778'),
#  ('Montgomery County, TX', 804876.0, '266,188', '20,537'),
#  ('San Francisco, CA metro area', 779511.0, '1,370,040', '10,543'),
#  ('Albany, NY metro area', 721525.0, '212,824', '17,177'),
#  ('Westchester County, NY', 697226.0, '526,153', '20,419'),
#  ('Erie County, NY', 669710.0, '158,826', '9,829'),
#  ('Fresno, CA metro area', 647646.0, '276,947', '9,501'),
#  ('Fresno County, CA', 647646.0, '276,947', '9,501'),
#  ('Monroe County, NY', 646266.0, '148,502', '7,992'),
#  ('Queens County, NY', 642580.0, '591,627', '31,450'),
#  ('Kern County, CA', 632677.0, '242,290', '11,661'),
#  ('Bakersfield, CA metro area', 632677.0, '242,290', '11,661'),
#  ('New York County, NY', 615962.0, '1,216,717', '49,302'),
#  ('Ventura County, CA', 601358.0, '612,655', '10,955'),
#  ('Oxnard, CA metro area', 601358.0, '612,655', '10,955'),
#  ('El Paso, TX metro area', 596919.0, '161,549', '15,549'),
#  ('El Paso County, TX', 592664.0, '161,456', '15,245'),
#  ('Stockton, CA metro area', 545239.0, '373,320', '7,598'),
#  ('San Joaquin County, CA', 545239.0, '373,320', '7,598'),
#  ('Placer County, CA', 511933.0, '495,685', '7,867'),
#  ('Syracuse, NY metro area', 504469.0, '140,741', '11,193'),
#  ('Kings County, NY', 493821.0, '855,623', '30,925'),
#  ('Galveston County, TX', 441880.0, '244,993', '10,961'),
#  ('Poughkeepsie, NY metro area', 435014.0, '268,233', '13,826'),
#  ('Killeen, TX metro area', 416643.0, '173,589', '7,788'),
#  ('Bell County, TX', 415031.0, '173,713', '7,694'),
#  ('Modesto, CA metro area', 405263.0, '322,960', '5,455'),
#  ('Stanislaus County, CA', 405263.0, '322,960', '5,455'),
#  ('San Mateo County, CA', 394155.0, '1,363,903', '4,447'),
#  ('San Francisco County, CA', 385356.0, '1,374,755', '6,096'),
#  ('Onondaga County, NY', 384697.0, '145,368', '7,607'),
#  ('Solano County, CA', 370258.0, '442,475', '4,964'),
#  ('Vallejo, CA metro area', 370258.0, '442,475', '4,964'),
#  ('Sonoma County, CA', 362960.0, '631,043', '6,863'),
#  ('Santa Rosa, CA metro area', 362960.0, '631,043', '6,863'),
#  ('Brazoria County, TX', 351228.0, '244,150', '7,709'),
#  ('Orange County, NY', 320413.0, '256,419', '10,024'),
#  ('Richmond County, NY', 296895.0, '544,680', '9,311'),
#  ('Hays County, TX', 279669.0, '277,656', '5,380'),
#  ('El Dorado County, CA', 269818.0, '493,510', '5,488'),
#  ('Santa Maria, CA metro area', 262318.0, '631,779', '5,890'),
#  ('Santa Barbara County, CA', 262318.0, '631,779', '5,890'),
#  ('San Luis Obispo County, CA', 257663.0, '605,503', '5,565'),
#  ('San Luis Obispo, CA metro area', 257663.0, '605,503', '5,565'),
#  ('McAllen, TX metro area', 236981.0, '157,170', '10,408'),
#  ('Hidalgo County, TX', 236981.0, '157,170', '10,408'),
#  ('Comal County, TX', 232062.0, '310,560', '5,881'),
#  ('Albany County, NY', 229637.0, '217,287', '4,774'),
#  ('Guadalupe County, TX', 216757.0, '238,236', '4,595'),
#  ('Ellis County, TX', 211304.0, '265,280', '3,979'),
#  ('Saratoga County, NY', 206383.0, '287,544', '5,422'),
#  ('Marin County, CA', 206369.0, '1,177,502', '3,202'),
#  ('San Rafael, CA metro area', 206369.0, '1,177,502', '3,202'),
#  ('Kaufman County, TX', 204566.0, '233,152', '4,009'),
#  ('Parker County, TX', 202961.0, '292,727', '4,757'),
#  ('Monterey County, CA', 202946.0, '622,643', '4,917'),
#  ('Salinas, CA metro area', 202946.0, '622,643', '4,917'),
#  ('Rockland County, NY', 202659.0, '421,334', '6,405'),
#  ('Butte County, CA', 192260.0, '325,944', '3,319'),
#  ('Chico, CA metro area', 192260.0, '325,944', '3,319'),
#  ('Johnson County, TX', 186660.0, '224,671', '3,485'),
#  ('Merced County, CA', 175119.0, '281,597', '3,356'),
#  ('Merced, CA metro area', 175119.0, '281,597', '3,356'),
#  ('Abilene, TX metro area', 171352.0, '169,630', '3,750'),
#  ('Rockwall County, TX', 168359.0, '297,619', '3,692'),
#  ('Santa Cruz County, CA', 162967.0, '829,221', '3,198'),
#  ('Santa Cruz, CA metro area', 162967.0, '829,221', '3,198'),
#  ('Nevada County, CA', 161678.0, '476,797', '2,932'),
#  ('Truckee, CA metro area', 161678.0, '476,797', '2,932'),
#  ('Niagara County, NY', 161571.0, '126,147', '2,949'),
#  ('Bronx County, NY', 160436.0, '470,511', '7,166'),
#  ('Taylor County, TX', 153733.0, '174,876', '3,203'),
#  ('Grayson County, TX', 150250.0, '185,846', '3,683'),
#  ('Sherman, TX metro area', 150250.0, '185,846', '3,683'),
#  ('Schenectady County, NY', 148163.0, '162,159', '3,349'),
#  ('Yolo County, CA', 131465.0, '443,057', '1,722'),
#  ('Rensselaer County, NY', 117304.0, '183,911', '2,849'),
#  ('Madera County, CA', 117173.0, '279,473', '2,720'),
#  ('Madera, CA metro area', 117173.0, '279,473', '2,720'),
#  ('Dutchess County, NY', 114601.0, '298,153', '3,802'),
#  ('Glens Falls, NY metro area', 108625.0, '176,923', '4,684'),
#  ('Hood County, TX', 104175.0, '243,095', '2,168'),
#  ('Granbury, TX metro area', 104175.0, '243,095', '2,168'),
#  ('Napa, CA metro area', 95296.0, '697,184', '2,307'),
#  ('Napa County, CA', 95296.0, '697,184', '2,307'),
#  ('Putnam County, NY', 90218.0, '338,156', '2,907'),
#  ('Ontario County, NY', 89783.0, '184,914', '2,043'),
#  ('Hunt County, TX', 88901.0, '187,588', '1,867'),
#  ('Chautauqua County, NY', 87160.0, '93,393', '2,618'),
#  ('Jamestown, NY metro area', 87160.0, '93,393', '2,618'),
#  ('Oswego County, NY', 75503.0, '109,118', '2,286'),
#  ('Bastrop County, TX', 72244.0, '247,901', '1,595'),
#  ('Wise County, TX', 71458.0, '243,784', '1,758'),
#  ('Wayne County, NY', 70184.0, '134,916', '1,277'),
#  ('Sullivan County, NY', 69096.0, '151,334', '3,933'),
#  ('Lake County, CA', 66261.0, '263,706', '2,484'),
#  ('Clearlake, CA metro area', 66261.0, '263,706', '2,484'),
#  ('Warren County, NY', 65038.0, '209,543', '2,753'),
#  ('Victoria, TX metro area', 61692.0, '184,478', '1,702'),
#  ('Victoria County, TX', 59318.0, '183,677', '1,578'),
#  ('Athens, TX metro area', 59078.0, '232,866', '1,947'),
#  ('Henderson County, TX', 59078.0, '232,866', '1,947'),
#  ('Waller County, TX', 52253.0, '276,298', '1,617'),
#  ('Chambers County, TX', 50556.0, '256,983', '1,147'),
#  ('Amador County, CA', 50443.0, '335,576', '1,227'),
#  ('Cattaraugus County, NY', 50100.0, '98,121', '1,995'),
#  ('Olean, NY metro area', 50100.0, '98,121', '1,995'),
#  ('Kendall County, TX', 49636.0, '402,443', '1,573'),
#  ('Auburn, NY metro area', 47087.0, '121,591', '1,483'),
#  ('Cayuga County, NY', 47087.0, '121,591', '1,483'),
#  ('Madison County, NY', 44269.0, '151,900', '1,299'),
#  ('Washington County, NY', 43587.0, '143,088', '1,931'),
#  ('San Benito County, CA', 43584.0, '592,196', '887'),
#  ('Liberty County, TX', 40363.0, '184,497', '1,398'),
#  ('Livingston County, NY', 39925.0, '136,895', '922'),
#  ('Fulton County, NY', 38479.0, '111,131', '1,339'),
#  ('Gloversville, NY metro area', 38479.0, '111,131', '1,339'),
#  ('Burnet County, TX', 38450.0, '339,489', '1,270'),
#  ('Wilson County, TX', 35841.0, '320,139', '924'),
#  ('Huntsville, TX metro area', 33422.0, '202,557', '1,012'),
#  ('Walker County, TX', 33422.0, '202,557', '1,012'),
#  ('Batavia, NY metro area', 33419.0, '119,245', '634'),
#  ('Genesee County, NY', 33419.0, '119,245', '634'),
#  ('Erath County, TX', 32069.0, '183,143', '882'),
#  ('Stephenville, TX metro area', 32069.0, '183,143', '882'),
#  ('Corsicana, TX metro area', 31514.0, '158,955', '870'),
#  ('Navarro County, TX', 31514.0, '158,955', '870'),
#  ('Gainesville, TX metro area', 31210.0, '222,125', '857'),
#  ('Cooke County, TX', 31210.0, '222,125', '857'),
#  ('Brown County, TX', 30931.0, '149,124', '989'),
#  ('Brownwood, TX metro area', 30931.0, '149,124', '989'),
#  ('Medina County, TX', 30305.0, '267,378', '814'),
#  ('Mineral Wells, TX metro area', 30168.0, '215,076', '1,296'),
#  ('Palo Pinto County, TX', 30168.0, '215,076', '1,296'),
#  ('Bonham, TX metro area', 26816.0, '166,692', '756'),
#  ('Fannin County, TX', 26816.0, '166,692', '756'),
#  ('Amsterdam, NY metro area', 26326.0, '103,854', '891'),
#  ('Montgomery County, NY', 26326.0, '103,854', '891'),
#  ('Orleans County, NY', 25829.0, '108,036', '573'),
#  ('Hill County, TX', 25690.0, '153,986', '795'),
#  ('Allegany County, NY', 24916.0, '81,856', '964'),
#  ('Brenham, TX metro area', 23635.0, '276,441', '738'),
#  ('Washington County, TX', 23635.0, '276,441', '738'),
#  ('San Jacinto County, TX', 22764.0, '187,989', '936'),
#  ('Nueces County, TX', 22108.0, '218,416', '10,514'),
#  ('Wyoming County, NY', 22074.0, '110,242', '570'),
#  ('Sulphur Springs, TX metro area', 20361.0, '172,994', '552'),
#  ('Hopkins County, TX', 20361.0, '172,994', '552'),
#  ('Caldwell County, TX', 20146.0, '209,653', '493'),
#  ('Schoharie County, NY', 20038.0, '139,970', '784'),
#  ('Austin County, TX', 19618.0, '271,998', '773'),
#  ('Calaveras County, CA', 18207.0, '399,351', '336'),
#  ('El Campo, TX metro area', 17901.0, '169,303', '709'),
#  ('Wharton County, TX', 17901.0, '169,303', '709'),
#  ('Atascosa County, TX', 17745.0, '201,528', '548'),
#  ('Glenn County, CA', 15647.0, '262,871', '389'),
#  ('Montague County, TX', 15058.0, '149,641', '529'),
#  ('Fayette County, TX', 12419.0, '342,632', '610'),
#  ('Bandera County, TX', 11449.0, '246,098', '442'),
#  ('Colorado County, TX', 11004.0, '269,963', '489'),
#  ('Young County, TX', 10035.0, '146,176', '427'),
#  ('Eastland County, TX', 9799.0, '145,214', '496'),
#  ('Comanche County, TX', 9538.0, '156,740', '393'),
#  ('Houston County, TX', 9474.0, '175,198', '545'),
#  ('Callahan County, TX', 9357.0, '142,229', '265'),
#  ('Jones County, TX', 8262.0, '125,305', '299'),
#  ('Lavaca County, TX', 7113.0, '200,453', '327'),
#  ('Somervell County, TX', 6474.0, '287,574', '224'),
#  ('Lee County, TX', 6291.0, '239,203', '202'),
#  ('Stephens County, TX', 6072.0, '144,462', '249'),
#  ('Hamilton County, TX', 5861.0, '188,537', '263'),
#  ('Gonzales County, TX', 5363.0, '207,772', '278'),
#  ('DeWitt County, TX', 5241.0, '175,798', '251'),
#  ('Coleman County, TX', 4445.0, '141,006', '285'),
#  ('Hudspeth County, TX', 4255.0, '193,244', '347'),
#  ('Delta County, TX', 3508.0, '127,679', '120'),
#  ('Haskell County, TX', 3461.0, '81,431', '198'),
#  ('Aransas County, TX', 3027.0, '281,411', '1,085'),
#  ('Rockport, TX metro area', 3027.0, '281,411', '1,085'),
#  ('Rio Grande City, TX metro area', 2936.0, '126,311', '344'),
#  ('Starr County, TX', 2936.0, '126,311', '344'),
#  ('Jack County, TX', 2755.0, '233,915', '128'),
#  ('Goliad County, TX', 2374.0, '250,279', '149'),
#  ('Frio County, TX', 2180.0, '119,781', '120'),
#  ('Pearsall, TX metro area', 2180.0, '119,781', '120'),
#  ('Mills County, TX', 1984.0, '319,160', '171'),
#  ('Karnes County, TX', 1761.0, '152,804', '119'),
#  ('Nolan County, TX', 1227.0, '163,598', '74'),
#  ('Sweetwater, TX metro area', 1227.0, '163,598', '74'),
#  ('Fisher County, TX', 1170.0, '94,403', '80'),
#  ('Live Oak County, TX', 849.0, '147,376', '223'),
#  ('San Patricio County, TX', 647.0, '285,414', '2,195'),
#  ('Refugio County, TX', 624.0, '127,046', '146'),
#  ('Shackelford County, TX', 583.0, '230,162', '56'),
#  ('Jim Wells County, TX', 289.0, '132,702', '720'),
#  ('Kleberg County, TX', 289.0, '170,189', '345'),
#  ('Alice, TX metro area', 289.0, '132,702', '738'),
#  ('Kingsville, TX metro area', 289.0, '170,189', '345'),
#  ('Stonewall County, TX', 175.0, '97,941', '10'),
#  ('Throckmorton County, TX', 136.0, '83,850', '31')]

# %% [markdown]
# #### Discovery:
# After running this query, I found that there were many NULL results for different regions. I presume this was mostly due to the lack of reporting for some smaller regions in the US that either Redfin has not expanded their services to or simply do not have organized real estate registries available for analysis.

# %% [markdown]
# ### 2.
# #### Connect each county with their corresponding 2019 median household income.
#
# #### Purpose: Understand which counties are wealthier on average, which will most likely be reflected in property prices.
#
# #### Estimated Run Time: ~53 seconds

# %%
# %%sql
# SELECT
#     hd.region_name,
#     chi.countyName,
#     chi.medianHouseholdIncome
# FROM housing_data hd
# JOIN countyHouseholdIncome chi
#     ON hd.region_name LIKE chi.countyName
# GROUP BY region_name
# LIMIT 100;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 100 rows affected.
# [('Alameda County, CA', 'Alameda County, CA', 107589),
#  ('Amador County, CA', 'Amador County, CA', 62640),
#  ('Butte County, CA', 'Butte County, CA', 58394),
#  ('Calaveras County, CA', 'Calaveras County, CA', 68248),
#  ('Contra Costa County, CA', 'Contra Costa County, CA', 106555),
#  ('El Dorado County, CA', 'El Dorado County, CA', 86202),
#  ('Fresno County, CA', 'Fresno County, CA', 56926),
#  ('Glenn County, CA', 'Glenn County, CA', 55682),
#  ('Kern County, CA', 'Kern County, CA', 53245),
#  ('Lake County, CA', 'Lake County, CA', 46897),
#  ('Los Angeles County, CA', 'Los Angeles County, CA', 72721),
#  ('Madera County, CA', 'Madera County, CA', 61105),
#  ('Marin County, CA', 'Marin County, CA', 112069),
#  ('Merced County, CA', 'Merced County, CA', 59733),
#  ('Monterey County, CA', 'Monterey County, CA', 76509),
#  ('Napa County, CA', 'Napa County, CA', 90230),
#  ('Nevada County, CA', 'Nevada County, CA', 69550),
#  ('Orange County, CA', 'Orange County, CA', 95761),
#  ('Placer County, CA', 'Placer County, CA', 97688),
#  ('Riverside County, CA', 'Riverside County, CA', 72905),
#  ('Sacramento County, CA', 'Sacramento County, CA', 71891),
#  ('San Benito County, CA', 'San Benito County, CA', 84209),
#  ('San Bernardino County, CA', 'San Bernardino County, CA', 67398),
#  ('San Diego County, CA', 'San Diego County, CA', 83576),
#  ('San Joaquin County, CA', 'San Joaquin County, CA', 68458),
#  ('San Luis Obispo County, CA', 'San Luis Obispo County, CA', 76599),
#  ('San Mateo County, CA', 'San Mateo County, CA', 135234),
#  ('Santa Barbara County, CA', 'Santa Barbara County, CA', 74530),
#  ('Santa Clara County, CA', 'Santa Clara County, CA', 132444),
#  ('Santa Cruz County, CA', 'Santa Cruz County, CA', 85770),
#  ('Solano County, CA', 'Solano County, CA', 85704),
#  ('Sonoma County, CA', 'Sonoma County, CA', 87084),
#  ('Stanislaus County, CA', 'Stanislaus County, CA', 62761),
#  ('Ventura County, CA', 'Ventura County, CA', 91446),
#  ('Yolo County, CA', 'Yolo County, CA', 70951),
#  ('Aransas County, TX', 'Aransas County, TX', 53085),
#  ('Atascosa County, TX', 'Atascosa County, TX', 57309),
#  ('Austin County, TX', 'Austin County, TX', 68311),
#  ('Bandera County, TX', 'Bandera County, TX', 59604),
#  ('Bell County, TX', 'Bell County, TX', 54831),
#  ('Bexar County, TX', 'Bexar County, TX', 58956),
#  ('Brazoria County, TX', 'Brazoria County, TX', 83704),
#  ('Brown County, TX', 'Brown County, TX', 56040),
#  ('Burnet County, TX', 'Burnet County, TX', 62827),
#  ('Caldwell County, TX', 'Caldwell County, TX', 55301),
#  ('Callahan County, TX', 'Callahan County, TX', 50812),
#  ('Chambers County, TX', 'Chambers County, TX', 93351),
#  ('Coleman County, TX', 'Coleman County, TX', 44834),
#  ('Collin County, TX', 'Collin County, TX', 96847),
#  ('Comal County, TX', 'Comal County, TX', 87976),
#  ('Comanche County, TX', 'Comanche County, TX', 54122),
#  ('Cooke County, TX', 'Cooke County, TX', 61186),
#  ('Dallas County, TX', 'Dallas County, TX', 61807),
#  ('Delta County, TX', 'Delta County, TX', 51348),
#  ('Denton County, TX', 'Denton County, TX', 90910),
#  ('DeWitt County, TX', 'DeWitt County, TX', 52544),
#  ('Eastland County, TX', 'Eastland County, TX', 46991),
#  ('Ellis County, TX', 'Ellis County, TX', 78341),
#  ('El Paso County, TX', 'El Paso County, TX', 48629),
#  ('Erath County, TX', 'Erath County, TX', 53044),
#  ('Fannin County, TX', 'Fannin County, TX', 56123),
#  ('Fayette County, TX', 'Fayette County, TX', 62195),
#  ('Fisher County, TX', 'Fisher County, TX', 51053),
#  ('Fort Bend County, TX', 'Fort Bend County, TX', 101361),
#  ('Frio County, TX', 'Frio County, TX', 40360),
#  ('Goliad County, TX', 'Goliad County, TX', 56758),
#  ('Gonzales County, TX', 'Gonzales County, TX', 48425),
#  ('Grayson County, TX', 'Grayson County, TX', 57439),
#  ('Guadalupe County, TX', 'Guadalupe County, TX', 78801),
#  ('Hamilton County, TX', 'Hamilton County, TX', 52505),
#  ('Harris County, TX', 'Harris County, TX', 61638),
#  ('Haskell County, TX', 'Haskell County, TX', 38613),
#  ('Hays County, TX', 'Hays County, TX', 72890),
#  ('Henderson County, TX', 'Henderson County, TX', 49896),
#  ('Hidalgo County, TX', 'Hidalgo County, TX', 41656),
#  ('Hill County, TX', 'Hill County, TX', 53210),
#  ('Hopkins County, TX', 'Hopkins County, TX', 50332),
#  ('Houston County, TX', 'Houston County, TX', 43601),
#  ('Hudspeth County, TX', 'Hudspeth County, TX', 39309),
#  ('Hunt County, TX', 'Hunt County, TX', 57513),
#  ('Jack County, TX', 'Jack County, TX', 55358),
#  ('Jim Wells County, TX', 'Jim Wells County, TX', 44444),
#  ('Johnson County, TX', 'Johnson County, TX', 66538),
#  ('Jones County, TX', 'Jones County, TX', 51094),
#  ('Karnes County, TX', 'Karnes County, TX', 54843),
#  ('Kaufman County, TX', 'Kaufman County, TX', 75009),
#  ('Kleberg County, TX', 'Kleberg County, TX', 47169),
#  ('Lavaca County, TX', 'Lavaca County, TX', 52632),
#  ('Lee County, TX', 'Lee County, TX', 59250),
#  ('Liberty County, TX', 'Liberty County, TX', 53274),
#  ('Live Oak County, TX', 'Live Oak County, TX', 54163),
#  ('Medina County, TX', 'Medina County, TX', 60695),
#  ('Mills County, TX', 'Mills County, TX', 46876),
#  ('Montague County, TX', 'Montague County, TX', 53649),
#  ('Montgomery County, TX', 'Montgomery County, TX', 88833),
#  ('Navarro County, TX', 'Navarro County, TX', 48649),
#  ('Nueces County, TX', 'Nueces County, TX', 56079),
#  ('Palo Pinto County, TX', 'Palo Pinto County, TX', 50159),
#  ('Parker County, TX', 'Parker County, TX', 82501),
#  ('Refugio County, TX', 'Refugio County, TX', 46883)]

# %% [markdown]
# #### Discovery:
# After running the above query, I made sure that the housing_data VIEW and medianHouseholdIncome table were properly connected based on their shared region names, generally the names of specific US counties.

# %% [markdown]
# ### 3.
# #### List out all of the weekly periods for specific counties. In the housing_data table, each county has many period ranges, from weekly, to monthly, to quarterly. For the purposes of my queries, I will just be utilizing the weekly data.
#
# #### Purpose: Understand the time structure of the housing_data table. Each county has 52 weeks worth of data in each year, from 2017 and after.
#
# #### Estimated Run Time: ~1 second

# %%
# %%sql
# SELECT
#     region_name,
#     period_begin,
#     period_end,
#     DATEDIFF(period_end, period_begin) AS period_length,
#     total_homes_sold,
#     median_sale_price
# FROM housing_data hd
# WHERE YEAR(period_begin) = '2017'
#     AND DATEDIFF(period_end, period_begin) = 6
#     AND region_name = 'Los Angeles County, CA'
# ORDER BY period_begin;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 52 rows affected.
# [('Los Angeles County, CA', '2017-01-02', '2017-01-08', 6, 958.0, 543750.0),
#  ('Los Angeles County, CA', '2017-01-09', '2017-01-15', 6, 1146.0, 560000.0),
#  ('Los Angeles County, CA', '2017-01-16', '2017-01-22', 6, 1037.0, 550000.0),
#  ('Los Angeles County, CA', '2017-01-23', '2017-01-29', 6, 1140.0, 521000.0),
#  ('Los Angeles County, CA', '2017-01-30', '2017-02-05', 6, 1231.0, 525000.0),
#  ('Los Angeles County, CA', '2017-02-06', '2017-02-12', 6, 924.0, 528750.0),
#  ('Los Angeles County, CA', '2017-02-13', '2017-02-19', 6, 1220.0, 547500.0),
#  ('Los Angeles County, CA', '2017-02-20', '2017-02-26', 6, 1089.0, 545000.0),
#  ('Los Angeles County, CA', '2017-02-27', '2017-03-05', 6, 1450.0, 547450.0),
#  ('Los Angeles County, CA', '2017-03-06', '2017-03-12', 6, 1281.0, 563000.0),
#  ('Los Angeles County, CA', '2017-03-13', '2017-03-19', 6, 1325.0, 565000.0),
#  ('Los Angeles County, CA', '2017-03-20', '2017-03-26', 6, 1431.0, 560000.0),
#  ('Los Angeles County, CA', '2017-03-27', '2017-04-02', 6, 1804.0, 550000.0),
#  ('Los Angeles County, CA', '2017-04-03', '2017-04-09', 6, 1324.0, 560757.0),
#  ('Los Angeles County, CA', '2017-04-10', '2017-04-16', 6, 1430.0, 560000.0),
#  ('Los Angeles County, CA', '2017-04-17', '2017-04-23', 6, 1474.0, 556000.0),
#  ('Los Angeles County, CA', '2017-04-24', '2017-04-30', 6, 1739.0, 563000.0),
#  ('Los Angeles County, CA', '2017-05-01', '2017-05-07', 6, 1489.0, 570500.0),
#  ('Los Angeles County, CA', '2017-05-08', '2017-05-14', 6, 1546.0, 580000.0),
#  ('Los Angeles County, CA', '2017-05-15', '2017-05-21', 6, 1577.0, 573500.0),
#  ('Los Angeles County, CA', '2017-05-22', '2017-05-28', 6, 1713.0, 585000.0),
#  ('Los Angeles County, CA', '2017-05-29', '2017-06-04', 6, 1677.0, 580000.0),
#  ('Los Angeles County, CA', '2017-06-05', '2017-06-11', 6, 1608.0, 588500.0),
#  ('Los Angeles County, CA', '2017-06-12', '2017-06-18', 6, 1698.0, 580000.0),
#  ('Los Angeles County, CA', '2017-06-19', '2017-06-25', 6, 1669.0, 585000.0),
#  ('Los Angeles County, CA', '2017-06-26', '2017-07-02', 6, 2237.0, 591500.0),
#  ('Los Angeles County, CA', '2017-07-03', '2017-07-09', 6, 1211.0, 590000.0),
#  ('Los Angeles County, CA', '2017-07-10', '2017-07-16', 6, 1557.0, 585000.0),
#  ('Los Angeles County, CA', '2017-07-17', '2017-07-23', 6, 1579.0, 600000.0),
#  ('Los Angeles County, CA', '2017-07-24', '2017-07-30', 6, 1756.0, 580500.0),
#  ('Los Angeles County, CA', '2017-07-31', '2017-08-06', 6, 1721.0, 590000.0),
#  ('Los Angeles County, CA', '2017-08-07', '2017-08-13', 6, 1514.0, 595000.0),
#  ('Los Angeles County, CA', '2017-08-14', '2017-08-20', 6, 1604.0, 585000.0),
#  ('Los Angeles County, CA', '2017-08-21', '2017-08-27', 6, 1544.0, 590000.0),
#  ('Los Angeles County, CA', '2017-08-28', '2017-09-03', 6, 2069.0, 585000.0),
#  ('Los Angeles County, CA', '2017-09-04', '2017-09-10', 6, 1240.0, 600000.0),
#  ('Los Angeles County, CA', '2017-09-11', '2017-09-17', 6, 1521.0, 585000.0),
#  ('Los Angeles County, CA', '2017-09-18', '2017-09-24', 6, 1581.0, 590000.0),
#  ('Los Angeles County, CA', '2017-09-25', '2017-10-01', 6, 1794.0, 585000.0),
#  ('Los Angeles County, CA', '2017-10-02', '2017-10-08', 6, 1360.0, 570000.0),
#  ('Los Angeles County, CA', '2017-10-09', '2017-10-15', 6, 1248.0, 582250.0),
#  ('Los Angeles County, CA', '2017-10-16', '2017-10-22', 6, 1545.0, 572500.0),
#  ('Los Angeles County, CA', '2017-10-23', '2017-10-29', 6, 1501.0, 589000.0),
#  ('Los Angeles County, CA', '2017-10-30', '2017-11-05', 6, 1618.0, 590000.0),
#  ('Los Angeles County, CA', '2017-11-06', '2017-11-12', 6, 1166.0, 583750.0),
#  ('Los Angeles County, CA', '2017-11-13', '2017-11-19', 6, 1563.0, 590000.0),
#  ('Los Angeles County, CA', '2017-11-20', '2017-11-26', 6, 1087.0, 585000.0),
#  ('Los Angeles County, CA', '2017-11-27', '2017-12-03', 6, 1624.0, 585000.0),
#  ('Los Angeles County, CA', '2017-12-04', '2017-12-10', 6, 1251.0, 610500.0),
#  ('Los Angeles County, CA', '2017-12-11', '2017-12-17', 6, 1382.0, 575000.0),
#  ('Los Angeles County, CA', '2017-12-18', '2017-12-24', 6, 1541.0, 595000.0),
#  ('Los Angeles County, CA', '2017-12-25', '2017-12-31', 6, 1446.0, 578300.0)]

# %% [markdown]
# #### Discovery:
# The above query revealed that each region had data for each of the 52 weeks of a year, which reflects how often the public dataset is modified and published by Redfin. This was useful to base the rest of my yearly calculations off of since there seemed to be a lot of overlapping data in terms of the dates covered.

# %% [markdown]
# ### 4.
# #### DISPLAY total property sales each year and calculate year-over-year sales changes.
#
# #### Purpose: Understand which housing markets have experienced the highest growth since 2017.
#
# #### Estimated Run Time: ~16 seconds

# %%
# %%sql
# SELECT
#     DISTINCT(hd.region_name),
#     hst.home_sale_year_total_2017,
#     hst2.home_sale_year_total_2018,
#     hst3.home_sale_year_total_2019,
#     hst4.home_sale_year_total_2020,
#     (
#         (
#             (hst2.home_sale_year_total_2018 / hst.home_sale_year_total_2017) +
#             (hst3.home_sale_year_total_2019 / hst2.home_sale_year_total_2018) +
#             (hst4.home_sale_year_total_2020 / hst3.home_sale_year_total_2019)
#         ) / 3
#     ) AS avg_yoy_sales_change
# FROM housing_data hd
# JOIN home_sale_totals_2017 hst
#     ON hd.region_name = hst.region_name
# JOIN home_sale_totals_2018 hst2
#     ON hd.region_name = hst2.region_name
# JOIN home_sale_totals_2019 hst3
#     ON hd.region_name = hst3.region_name
# JOIN home_sale_totals_2020 hst4
#     ON hd.region_name = hst4.region_name
# WHERE hst.home_sale_year_total_2017 > 1000
# ORDER BY avg_yoy_sales_change DESC;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 128 rows affected.
# [('Comal County, TX', 2633.0, 3042.0, 3443.0, 4056.0, 1.155066564552729),
#  ('Kaufman County, TX', 2493.0, 2731.0, 2848.0, 3549.0, 1.1281487996438149),
#  ('Hays County, TX', 3413.0, 3759.0, 4005.0, 4731.0, 1.1160311442657427),
#  ('Hunt County, TX', 1111.0, 1127.0, 1267.0, 1512.0, 1.1106650694581144),
#  ('El Paso, TX metro area', 7211.0, 8012.0, 8710.0, 9848.0, 1.1096180117401386),
#  ('El Paso County, TX', 7186.0, 7948.0, 8660.0, 9756.0, 1.1073935658659668),
#  ('Johnson County, TX', 2414.0, 2629.0, 2461.0, 3119.0, 1.0975107191211038),
#  ('Montgomery County, TX', 10215.0, 10634.0, 11331.0, 13326.0, 1.0942094170562402),
#  ('Brazoria County, TX', 4410.0, 4793.0, 5041.0, 5754.0, 1.0933434623104985),
#  ('McAllen, TX metro area', 2983.0, 3033.0, 3542.0, 3870.0, 1.0923951127006042),
#  ('Hidalgo County, TX', 2983.0, 3033.0, 3542.0, 3870.0, 1.0923951127006042),
#  ('Ellis County, TX', 2689.0, 2865.0, 3085.0, 3479.0, 1.0899851401109988),
#  ('Dutchess County, NY', 1450.0, 1462.0, 1691.0, 1846.0, 1.0855241158690645),
#  ('Rockwall County, TX', 2207.0, 2262.0, 2361.0, 2794.0, 1.0840280502753539),
#  ('Fort Bend County, TX', 11565.0, 12248.0, 13054.0, 14625.0, 1.081736805804939),
#  ('Bell County, TX', 5319.0, 5594.0, 6180.0, 6673.0, 1.0787433350560247),
#  ('Killeen, TX metro area', 5325.0, 5601.0, 6181.0, 6679.0, 1.0786511366763456),
#  ('El Dorado County, CA', 3807.0, 3642.0, 3397.0, 4560.0, 1.077249654253486),
#  ('Williamson County, TX', 10919.0, 11137.0, 12335.0, 13517.0, 1.074453150063375),
#  ('Sherman, TX metro area', 2016.0, 2001.0, 2097.0, 2426.0, 1.0658087773931004),
#  ('Grayson County, TX', 2016.0, 2001.0, 2097.0, 2426.0, 1.0658087773931004),
#  ('Galveston County, TX', 5705.0, 6172.0, 6399.0, 6880.0, 1.0646016720749383),
#  ('Parker County, TX', 2711.0, 2840.0, 2795.0, 3230.0, 1.0624579698543115),
#  ('Putnam County, NY', 1205.0, 1219.0, 1199.0, 1428.0, 1.062067953370674),
#  ('Austin, TX metro area', 33514.0, 34749.0, 36967.0, 39914.0, 1.0601330655053138),
#  ('San Antonio, TX metro area', 31293.0, 32301.0, 34248.0, 37156.0, 1.0591328386969918),
#  ('Wise County, TX', 1019.0, 881.0, 990.0, 1177.0, 1.059061680593217),
#  ('Chautauqua County, NY', 1113.0, 1236.0, 1266.0, 1319.0, 1.058882704353595),
#  ('Jamestown, NY metro area', 1113.0, 1236.0, 1266.0, 1319.0, 1.058882704353595),
#  ('Houston, TX metro area', 83209.0, 87083.0, 90545.0, 98571.0, 1.0583178823554114),
#  ('Truckee, CA metro area', 2249.0, 2160.0, 2221.0, 2629.0, 1.0574562108969727),
#  ('Nevada County, CA', 2249.0, 2160.0, 2221.0, 2629.0, 1.0574562108969727),
#  ('Guadalupe County, TX', 2878.0, 3060.0, 3085.0, 3378.0, 1.0554613278098606),
#  ('Abilene, TX metro area', 2336.0, 2358.0, 2388.0, 2725.0, 1.0544209108621874),
#  ('Denton County, TX', 15218.0, 14859.0, 15816.0, 17748.0, 1.0543232352932412),
#  ('Taylor County, TX', 2100.0, 2120.0, 2139.0, 2437.0, 1.0526011705766396),
#  ('Bexar County, TX', 23964.0, 24257.0, 25558.0, 27385.0, 1.045781714200832),
#  ('Madera County, CA', 1636.0, 1548.0, 1675.0, 1821.0, 1.0384719305741277),
#  ('Madera, CA metro area', 1636.0, 1548.0, 1675.0, 1821.0, 1.0384719305741277),
#  ('Dallas, TX metro area', 66237.0, 65100.0, 67421.0, 73888.0, 1.0381356260754266),
#  ('Travis County, TX', 17998.0, 18669.0, 19328.0, 20127.0, 1.0379733564377582),
#  ('Collin County, TX', 16778.0, 16623.0, 16933.0, 18692.0, 1.037763523138797),
#  ('Harris County, TX', 49459.0, 51059.0, 52326.0, 55176.0, 1.0372102295323422),
#  ('Hood County, TX', 1493.0, 1424.0, 1404.0, 1618.0, 1.030720345153367),
#  ('Granbury, TX metro area', 1493.0, 1424.0, 1404.0, 1618.0, 1.030720345153367),
#  ('Poughkeepsie, NY metro area', 5952.0, 6046.0, 6105.0, 6434.0, 1.026480594223797),
#  ('Fort Worth, TX metro area', 34280.0, 34373.0, 34668.0, 36827.0, 1.0245239068603609),
#  ('Placer County, CA', 7428.0, 7028.0, 6985.0, 7844.0, 1.021003043268977),
#  ('Glens Falls, NY metro area', 1591.0, 1526.0, 1426.0, 1660.0, 1.0192365879655272),
#  ('Rockland County, NY', 2909.0, 2706.0, 2791.0, 3053.0, 1.0185004702538418),
#  ('Merced County, CA', 2405.0, 2540.0, 2565.0, 2528.0, 1.017183541517013),
#  ('Merced, CA metro area', 2405.0, 2540.0, 2565.0, 2528.0, 1.017183541517013),
#  ('Marin County, CA', 2936.0, 2833.0, 2900.0, 3079.0, 1.016764078406536),
#  ('San Rafael, CA metro area', 2936.0, 2833.0, 2900.0, 3079.0, 1.016764078406536),
#  ('Tarrant County, TX', 28136.0, 28023.0, 28422.0, 29301.0, 1.0137162813805658),
#  ('Bakersfield, CA metro area', 8791.0, 9033.0, 9074.0, 9126.0, 1.0125992418981515),
#  ('Kern County, CA', 8791.0, 9033.0, 9074.0, 9126.0, 1.0125992418981515),
#  ('Rensselaer County, NY', 1654.0, 1736.0, 1608.0, 1694.0, 1.0097755505752286),
#  ('Santa Barbara County, CA', 3755.0, 3637.0, 3727.0, 3851.0, 1.0088638765522824),
#  ('Santa Maria, CA metro area', 3755.0, 3637.0, 3727.0, 3851.0, 1.0088638765522824),
#  ('Napa County, CA', 1406.0, 1337.0, 1278.0, 1431.0, 1.008838090818538),
#  ('Napa, CA metro area', 1406.0, 1337.0, 1278.0, 1431.0, 1.008838090818538),
#  ('Orange County, NY', 4502.0, 4584.0, 4414.0, 4588.0, 1.0068495464688874),
#  ('Schenectady County, NY', 2057.0, 2210.0, 2039.0, 2079.0, 1.0055406864057954),
#  ('Dallas County, TX', 25741.0, 24633.0, 25111.0, 26114.0, 1.0054344490766711),
#  ('Santa Rosa, CA metro area', 5352.0, 4962.0, 4936.0, 5397.0, 1.0050952280344576),
#  ('Sonoma County, CA', 5352.0, 4962.0, 4936.0, 5397.0, 1.0050952280344576),
#  ('Ontario County, NY', 1283.0, 1232.0, 1367.0, 1289.0, 1.0042560278899917),
#  ('Riverside County, CA', 36158.0, 34251.0, 34625.0, 36360.0, 1.002762314509594),
#  ('San Luis Obispo County, CA', 3752.0, 3574.0, 3632.0, 3763.0, 1.0016184109818471),
#  ('San Luis Obispo, CA metro area', 3752.0, 3574.0, 3632.0, 3763.0, 1.0016184109818471),
#  ('Albany, NY metro area', 10271.0, 10540.0, 10084.0, 10279.0, 1.000754683906724),
#  ('Suffolk County, NY', 16859.0, 17324.0, 17270.0, 16876.0, 1.000550171839837),
#  ('Albany County, NY', 3291.0, 3306.0, 3245.0, 3272.0, 0.9981423591806978),
#  ('Saratoga County, NY', 2961.0, 3017.0, 2918.0, 2940.0, 0.9978792954700927),
#  ('Monterey County, CA', 2925.0, 2976.0, 2796.0, 2890.0, 0.9968571609447977),
#  ('Salinas, CA metro area', 2925.0, 2976.0, 2796.0, 2890.0, 0.9968571609447977),
#  ('Oxnard, CA metro area', 8815.0, 8345.0, 8617.0, 8673.0, 0.9952583139209178),
#  ('Ventura County, CA', 8815.0, 8345.0, 8617.0, 8673.0, 0.9952583139209178),
#  ('San Diego County, CA', 37624.0, 35011.0, 35599.0, 36944.0, 0.9950421103288128),
#  ('San Diego, CA metro area', 37624.0, 35011.0, 35599.0, 36944.0, 0.9950421103288128),
#  ('Sacramento, CA metro area', 33820.0, 32535.0, 31377.0, 33031.0, 0.9930420210834034),
#  ('Nassau County, NY metro area', 30183.0, 30711.0, 30592.0, 29475.0, 0.9923685479987138),
#  ('Westchester County, NY', 10183.0, 9910.0, 9700.0, 9889.0, 0.9904948104794764),
#  ('Riverside, CA metro area', 60804.0, 57513.0, 56621.0, 58765.0, 0.9894105146315947),
#  ('Niagara County, NY', 2356.0, 2317.0, 2284.0, 2281.0, 0.9892968264609098),
#  ('Contra Costa County, CA', 14272.0, 13725.0, 13385.0, 13775.0, 0.9886793289142656),
#  ('San Francisco County, CA', 5456.0, 5661.0, 5428.0, 5233.0, 0.9868298912417434),
#  ('Santa Cruz County, CA', 2429.0, 2351.0, 2235.0, 2311.0, 0.9841839293172104),
#  ('Santa Cruz, CA metro area', 2429.0, 2351.0, 2235.0, 2311.0, 0.9841839293172104),
#  ('Rochester, NY metro area', 12749.0, 12649.0, 12697.0, 12114.0, 0.9833448852462242),
#  ('Anaheim, CA metro area', 32119.0, 29171.0, 29380.0, 30301.0, 0.9822429420218396),
#  ('Orange County, CA', 32119.0, 29171.0, 29380.0, 30301.0, 0.9822429420218396),
#  ('San Francisco, CA metro area', 11326.0, 11273.0, 10886.0, 10727.0, 0.9821282570148283),
#  ('Nassau County, NY', 13324.0, 13387.0, 13322.0, 12599.0, 0.9818672408565151),
#  ('Buffalo, NY metro area', 12050.0, 12204.0, 12014.0, 11386.0, 0.9816463560167185),
#  ('Monroe County, NY', 9474.0, 9455.0, 9370.0, 8937.0, 0.980931082062609),
#  ('Erie County, NY', 9694.0, 9887.0, 9730.0, 9105.0, 0.9799318192432169),
#  ('San Mateo County, CA', 5870.0, 5612.0, 5458.0, 5494.0, 0.9784007751273153),
#  ('Oakland, CA metro area', 28550.0, 27472.0, 26854.0, 26670.0, 0.9776313945669869),
#  ('Solano County, CA', 5621.0, 5151.0, 5215.0, 5234.0, 0.9774843644321106),
#  ('Vallejo, CA metro area', 5621.0, 5151.0, 5215.0, 5234.0, 0.9774843644321106),
#  ('Oswego County, NY', 1115.0, 1106.0, 1069.0, 1034.0, 0.9752444946367783),
#  ('San Joaquin County, CA', 8224.0, 7731.0, 7722.0, 7613.0, 0.974924614492037),
#  ('Stockton, CA metro area', 8224.0, 7731.0, 7722.0, 7613.0, 0.974924614492037),
#  ('Fresno County, CA', 9637.0, 9549.0, 9074.0, 8901.0, 0.9740198790533086),
#  ('Fresno, CA metro area', 9637.0, 9549.0, 9074.0, 8901.0, 0.9740198790533086),
#  ('Sacramento County, CA', 20549.0, 20035.0, 19165.0, 18779.0, 0.970473909183936),
#  ('Yolo County, CA', 2036.0, 1830.0, 1830.0, 1848.0, 0.9695524278828089),
#  ('Wayne County, NY', 1069.0, 978.0, 1018.0, 970.0, 0.9695407440794798),
#  ('San Bernardino County, CA', 24646.0, 23262.0, 21996.0, 22405.0, 0.9693385365015477),
#  ('Syracuse, NY metro area', 7657.0, 7226.0, 7172.0, 6964.0, 0.9690789830406604),
#  ('Alameda County, CA', 14278.0, 13747.0, 13469.0, 12895.0, 0.9666569816615241),
#  ('Onondaga County, NY', 5887.0, 5502.0, 5489.0, 5259.0, 0.9634456339077334),
#  ('Butte County, CA', 2753.0, 2930.0, 2977.0, 2404.0, 0.9626196023364869),
#  ('Chico, CA metro area', 2753.0, 2930.0, 2977.0, 2404.0, 0.9626196023364869),
#  ('Modesto, CA metro area', 6212.0, 5846.0, 5759.0, 5489.0, 0.9597722223977687),
#  ('Stanislaus County, CA', 6212.0, 5846.0, 5759.0, 5489.0, 0.9597722223977687),
#  ('San Jose, CA metro area', 16026.0, 14734.0, 13963.0, 13982.0, 0.9561379320000221),
#  ('Santa Clara County, CA', 15391.0, 14112.0, 13368.0, 13348.0, 0.9542274293879786),
#  ('Los Angeles County, CA', 76240.0, 70335.0, 68609.0, 64921.0, 0.9480845452568665),
#  ('Los Angeles, CA metro area', 76240.0, 70335.0, 68609.0, 64921.0, 0.9480845452568665),
#  ('New York, NY metro area', 70720.0, 68394.0, 66644.0, 60039.0, 0.9474713305836698),
#  ('Richmond County, NY', 4560.0, 4474.0, 3992.0, 3767.0, 0.9390146845594716),
#  ('Kings County, NY', 7560.0, 7251.0, 7109.0, 5999.0, 0.9278011247700776),
#  ('Queens County, NY', 9853.0, 9697.0, 9497.0, 7454.0, 0.9161405862557007),
#  ('Bronx County, NY', 2465.0, 2462.0, 2351.0, 1836.0, 0.9115473146612469),
#  ('New York County, NY', 10049.0, 9385.0, 9272.0, 6463.0, 0.8729760498766588)]

# %% [markdown]
# #### Discovery:
# After running this query, I was able to take a look at which regions have seen the greatest increases in home sale prices over the 2017-2020 period. I was surprised to see that many of the metro regions I initially suspected to be on there like Los Angeles, San Francisco, New York were not near the top of the list.

# %% [markdown]
# ### 5.
# #### This query compares the yearly average home sale prices across each county to see which markets have been increasing in price steadily over the past 4 years.
#
# #### Purpose: To provide a suitable and easily-modifiable subquery to search through for question #1, when attempting to collect data on the most and least successful housing markets over the 4-year period.
#
# #### Estimated Run Time ~ 1 second each

# %% [markdown]
# VIEW for counties with higest sale price change ratio over the 4-year period

# %%
# %%sql
# CREATE OR REPLACE VIEW yoy_sale_price_increase AS
# SELECT
#     hd.region_name AS region_name,
#     FORMAT(hst.avg_sale_price_2017, 0) AS avg_sale_price_2017,
#     FORMAT(hst2.avg_sale_price_2018, 0) AS avg_sale_price_2018,
#     FORMAT(hst3.avg_sale_price_2019, 0) AS avg_sale_price_2019,
#     FORMAT(hst4.avg_sale_price_2020, 0) AS avg_sale_price_2020,
#     (
#         (
#             (hst2.avg_sale_price_2018 / hst.avg_sale_price_2017) +
#             (hst3.avg_sale_price_2019 / hst2.avg_sale_price_2018) +
#             (hst4.avg_sale_price_2020 / hst3.avg_sale_price_2019)
#         ) / 3
#     ) AS yoy_sale_price_change
# FROM housing_data hd
# LEFT JOIN home_sale_totals_2017 hst
#     ON hd.region_name = hst.region_name
# LEFT JOIN home_sale_totals_2018 hst2
#     ON hd.region_name = hst2.region_name
# LEFT JOIN home_sale_totals_2019 hst3
#     ON hd.region_name = hst3.region_name
# LEFT JOIN home_sale_totals_2020 hst4
#     ON hd.region_name = hst4.region_name
# WHERE
#     (
#         (
#             (hst2.avg_sale_price_2018 / hst.avg_sale_price_2017) +
#             (hst3.avg_sale_price_2019 / hst2.avg_sale_price_2018) +
#             (hst4.avg_sale_price_2020 / hst3.avg_sale_price_2019)
#         ) / 3
#     ) > 1
# GROUP BY hd.region_name
# ORDER BY yoy_sale_price_change DESC
# LIMIT 50;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %% [markdown]
# VIEW for counties with the lowest sale price change ratio in the 4-year period

# %%
# %%sql
# CREATE OR REPLACE VIEW yoy_sales_price_decrease AS
# SELECT
#     hd.region_name AS region_name,
#     FORMAT(hst.avg_sale_price_2017, 0) AS avg_sale_price_2017,
#     FORMAT(hst2.avg_sale_price_2018, 0) AS avg_sale_price_2018,
#     FORMAT(hst3.avg_sale_price_2019, 0) AS avg_sale_price_2019,
#     FORMAT(hst4.avg_sale_price_2020, 0) AS avg_sale_price_2020,
#     (
#         (
#             (hst2.avg_sale_price_2018 / hst.avg_sale_price_2017) +
#             (hst3.avg_sale_price_2019 / hst2.avg_sale_price_2018) +
#             (hst4.avg_sale_price_2020 / hst3.avg_sale_price_2019)
#         ) / 3
#     ) AS yoy_sale_price_change
# FROM housing_data hd
# LEFT JOIN home_sale_totals_2017 hst
#     ON hd.region_name = hst.region_name
# LEFT JOIN home_sale_totals_2018 hst2
#     ON hd.region_name = hst2.region_name
# LEFT JOIN home_sale_totals_2019 hst3
#     ON hd.region_name = hst3.region_name
# LEFT JOIN home_sale_totals_2020 hst4
#     ON hd.region_name = hst4.region_name
# WHERE
#     (
#         (
#             (hst2.avg_sale_price_2018 / hst.avg_sale_price_2017) +
#             (hst3.avg_sale_price_2019 / hst2.avg_sale_price_2018) +
#             (hst4.avg_sale_price_2020 / hst3.avg_sale_price_2019)
#         ) / 3
#     ) < 1
# GROUP BY hd.region_name
# ORDER BY yoy_sale_price_change DESC
# LIMIT 50;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %% [markdown]
# VIEW displaying sale price changes for all counties no matter if they have decreased or increased

# %%
# %%sql
# CREATE OR REPLACE VIEW yoy_sales_price_change AS
# SELECT
#     hd.region_name AS region_name,
#     FORMAT(hst.avg_sale_price_2017, 0) AS avg_sale_price_2017,
#     FORMAT(hst2.avg_sale_price_2018, 0) AS avg_sale_price_2018,
#     FORMAT(hst3.avg_sale_price_2019, 0) AS avg_sale_price_2019,
#     FORMAT(hst4.avg_sale_price_2020, 0) AS avg_sale_price_2020,
#     (
#         (
#             (hst2.avg_sale_price_2018 / hst.avg_sale_price_2017) +
#             (hst3.avg_sale_price_2019 / hst2.avg_sale_price_2018) +
#             (hst4.avg_sale_price_2020 / hst3.avg_sale_price_2019)
#         ) / 3
#     ) AS yoy_sale_price_change
# FROM housing_data hd
# JOIN home_sale_totals_2017 hst
#     ON hd.region_name = hst.region_name
# JOIN home_sale_totals_2018 hst2
#     ON hd.region_name = hst2.region_name
# JOIN home_sale_totals_2019 hst3
#     ON hd.region_name = hst3.region_name
# JOIN home_sale_totals_2020 hst4
#     ON hd.region_name = hst4.region_name
# GROUP BY hd.region_name
# ORDER BY yoy_sale_price_change DESC;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %% [markdown]
# #### Discovery:
# These views were useful to create because they helped me formulate the queries for my main questions surrounding year-over-year home sale price and total homes sold data.

# %% [markdown]
# ### 6.
# #### CREATE VIEWS to organize data into yearly subsections for property sales and median property prices in each county
#
# ### Estimated Run Time: ~1 second each

# %%
# %%sql
# CREATE OR REPLACE VIEW home_sale_totals_2017 AS
# SELECT
#     DISTINCT(region_name),
#     SUM(total_homes_sold) OVER(PARTITION BY region_name) AS home_sale_year_total_2017,
#     AVG(median_sale_price) OVER(PARTITION BY region_name) AS avg_sale_price_2017
# FROM housing_data hd
# WHERE YEAR(period_begin) = '2017'
#     AND DATEDIFF(period_end, period_begin) = 6
# ORDER BY home_sale_year_total_2017 DESC, region_name;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %%
# %%sql
# CREATE OR REPLACE VIEW home_sale_totals_2018 AS
# SELECT
#     DISTINCT(region_name),
#     SUM(total_homes_sold) OVER(PARTITION BY region_name) AS home_sale_year_total_2018,
#     AVG(median_sale_price) OVER(PARTITION BY region_name) AS avg_sale_price_2018
# FROM housing_data hd
# WHERE YEAR(period_begin) = '2018'
#     AND DATEDIFF(period_end, period_begin) = 6
# ORDER BY home_sale_year_total_2018 DESC, region_name;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %%
# %%sql
# CREATE OR REPLACE VIEW home_sale_totals_2019 AS
# SELECT
#     DISTINCT(region_name),
#     SUM(total_homes_sold) OVER(PARTITION BY region_name) AS home_sale_year_total_2019,
#     AVG(median_sale_price) OVER(PARTITION BY region_name) AS avg_sale_price_2019
# FROM housing_data hd
# WHERE YEAR(period_begin) = '2019'
#     AND DATEDIFF(period_end, period_begin) = 6
# ORDER BY home_sale_year_total_2019 DESC, region_name;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %%
# %%sql
# CREATE OR REPLACE VIEW home_sale_totals_2020 AS
# SELECT
#     DISTINCT(region_name),
#     SUM(total_homes_sold) OVER(PARTITION BY region_name) AS home_sale_year_total_2020,
#     AVG(median_sale_price) OVER(PARTITION BY region_name) AS avg_sale_price_2020
# FROM housing_data hd
# WHERE YEAR(period_begin) = '2020'
#     AND DATEDIFF(period_end, period_begin) = 6
# ORDER BY home_sale_year_total_2020 DESC, region_name;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %%
# %%sql
# CREATE OR REPLACE VIEW home_sale_totals_2021 AS
# SELECT
#     DISTINCT(region_name),
#     SUM(total_homes_sold) OVER(PARTITION BY region_name) AS home_sale_year_total_2021,
#     AVG(median_sale_price) OVER(PARTITION BY region_name) AS avg_sale_price_2021
# FROM housing_data hd
# WHERE YEAR(period_begin) = '2021'
#     AND DATEDIFF(period_end, period_begin) = 6
# ORDER BY home_sale_year_total_2021 DESC, region_name;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %% [markdown]
# #### Discovery:
# These VIEWS were useful to collect yearly data on all of the counties based off of the 52-week-long periods recorded for each.

# %% [markdown]
# ## Primary Question
#
# ### Based on housing data collected between 2017 and 2020, how have the housing markets in county/metro regions in California, New York, and Texas performed and which regions provide the best potential investments for residential property buyers?
#
# ## Two Sub Questions
#
# ### 1.A: Which housing markets have seen the biggest boom out of the 3 studied between 2017-2020?
# ### 1.B: Which housing markets have seen the largest bust out of the 3 studied between 2017-2020?
#
# ### 2: How do home prices compare to the (2019) median household income in each county in 2020? Which counties have the lowest home price to household income ratio in 2020?
# ______________________________________________________________________________________________________________________

# %% [markdown]
# ### 1.A: Which housing markets have seen the biggest boom out of the 3 studied between 2017-2020?
# #### Business Justification:
# It is important for Redfin analysts to understand which counties/regions in the US have experienced the greatest housing booms over the past 4 years so that they can adjust their range of listings accordingly. By taking advantage of counties with high home sales and healthily increasing prices, Redfin can cater to these areas more where home buying is occuring the most.
#
# #### Estimated Run Time: ~1m 49s

# %%
# %%sql
# WITH cte_yoy_sales_data AS (
#     SELECT
#         DISTINCT(hd.region_name),
#         hst.home_sale_year_total_2017,
#         hst2.home_sale_year_total_2018,
#         hst3.home_sale_year_total_2019,
#         hst4.home_sale_year_total_2020,
#         (
#             (
#                 (hst2.home_sale_year_total_2018 / hst.home_sale_year_total_2017) +
#                 (hst3.home_sale_year_total_2019 / hst2.home_sale_year_total_2018) +
#                 (hst4.home_sale_year_total_2020 / hst3.home_sale_year_total_2019)
#             ) / 3
#         ) AS avg_yoy_sales_change
#     FROM housing_data hd
#     JOIN home_sale_totals_2017 hst
#         ON hd.region_name = hst.region_name
#     JOIN home_sale_totals_2018 hst2
#         ON hd.region_name = hst2.region_name
#     JOIN home_sale_totals_2019 hst3
#         ON hd.region_name = hst3.region_name
#     JOIN home_sale_totals_2020 hst4
#         ON hd.region_name = hst4.region_name
#     WHERE hst.home_sale_year_total_2017 > 1000
#     ORDER BY avg_yoy_sales_change DESC
# )
# SELECT
#     cte.region_name,
#     FORMAT(cte.avg_yoy_sales_change, 2) AS avg_yoy_home_sales_change,
#     FORMAT(yspi.yoy_sale_price_change, 2) AS avg_yoy_sale_price_change
# FROM cte_yoy_sales_data cte
# JOIN yoy_sale_price_increase yspi
#     ON cte.region_name = yspi.region_name
# WHERE cte.region_name IN
#     (
#         SELECT
#             region_name
#         FROM yoy_sale_price_increase yspi
#     )
#     AND cte.avg_yoy_sales_change > 1
# ORDER BY cte.avg_yoy_sales_change DESC
# LIMIT 10;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 6 rows affected.
# [('Chautauqua County, NY', '1.06', '1.10'),
#  ('Jamestown, NY metro area', '1.06', '1.10'),
#  ('Madera, CA metro area', '1.04', '1.09'),
#  ('Madera County, CA', '1.04', '1.09'),
#  ('Poughkeepsie, NY metro area', '1.03', '1.09'),
#  ('Orange County, NY', '1.01', '1.09')]

# %% [markdown]
# #### Recommendation:
# In the query above, I have collected the following data:
# - region name
# - average year-over-year total home sales change
# - average year-over-year sale price change
#
# As seen by the above results, contrary to popular belief about housing booms taking place in largely urban and metropolitan areas, the best growth in housing markets across California, New York, and Texas are actually taking place in more rural areas, such as Madera County in California, and Chautauqua County in New York. While metropolitan regions may boast the highest home sales and highest property prices, it is these areas that are actually growing at the healthiest rate. Because of this, I recommend that Redfin continue pushing these smaller but popular and healthy regions to consumers.

# %% [markdown]
# ### 1.B: Which housing markets have seen the largest bust out of the 3 studied between 2017-2020?
# #### Business Justification:
# As much as it is important to understand where the housing market has been the most successful, it is equally important to understand where it has suffered the most. Redfin analysts must recognize which regions are struggling or stagnating in the current California, Texas, and New York housing markets.
#
# #### Estimated Run Time: ~1m 45s

# %%
# %%sql
# WITH cte_yoy_sales_data AS (
#     SELECT
#         DISTINCT(hd.region_name),
#         hst.home_sale_year_total_2017,
#         hst2.home_sale_year_total_2018,
#         hst3.home_sale_year_total_2019,
#         hst4.home_sale_year_total_2020,
#         (
#             (
#                 (hst2.home_sale_year_total_2018 / hst.home_sale_year_total_2017) +
#                 (hst3.home_sale_year_total_2019 / hst2.home_sale_year_total_2018) +
#                 (hst4.home_sale_year_total_2020 / hst3.home_sale_year_total_2019)
#             ) / 3
#         ) AS avg_yoy_sales_change
#     FROM housing_data hd
#     JOIN home_sale_totals_2017 hst
#         ON hd.region_name = hst.region_name
#     JOIN home_sale_totals_2018 hst2
#         ON hd.region_name = hst2.region_name
#     JOIN home_sale_totals_2019 hst3
#         ON hd.region_name = hst3.region_name
#     JOIN home_sale_totals_2020 hst4
#         ON hd.region_name = hst4.region_name
#     WHERE hst.home_sale_year_total_2017 > 1000
#     ORDER BY avg_yoy_sales_change DESC
# )
# SELECT
#     cte.region_name,
#     FORMAT(cte.avg_yoy_sales_change, 2) AS avg_yoy_home_sales_change,
#     FORMAT(yspd.yoy_sale_price_change, 2) AS avg_yoy_sale_price_change
# FROM cte_yoy_sales_data cte
# JOIN yoy_sales_price_decrease yspd
#     ON cte.region_name = yspd.region_name
# WHERE cte.region_name IN
#     (
#         SELECT
#             yspd.region_name
#         FROM yoy_sales_price_decrease yspd
#     )
#     AND cte.avg_yoy_sales_change < 1
# ORDER BY cte.avg_yoy_sales_change
# LIMIT 10;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('New York County, NY', '0.87', '0.97')]

# %% [markdown]
# #### Recommendation:
# In the query below, I have collected the following data:
# - region name
# - average year-over-year total home sales change
# - average year-over-year sale price change
#
# Based on my query, and relating to the query results in Question 1.A, it is New York County, home to the greater part of New York City, with an approximate ~8.4 million people, that has been stagnating the most over the 4-year period. The bustling metropolis is known for its sky high home prices, making it inaccessible to most, and a symbol of success and status to some. However, while the data shows that New York County's housing market has struggled to stay healthy from 2017 to 2020, it has actually been reported that their housing market has been bouncing back over the past few months nearing the end of the COVID-19 pandemic, allowing for greater home sales and and reducing prices to more affordable levels. Because of this, I recommend that Redfin continue to direct consumers to smaller regions with healthier growth potential outside of metropolitan areas such as New York City.

# %% [markdown]
# ### 2. How do home prices compare to the (2019) median household income in each county in 2020? Which counties have the lowest home price to household income ratio in 2020?
#
# #### Business Justification:
# For Redfin it is important to understand the financial risks homebuyers are taking when purchasing property in different housing markets. By calculating the home price to income ratio across different counties, Redfin is able to get a better picture of who their potential customers are and what kinds of properties they are looking for cost-wise. Additionally, they can see which housing markets require buyers to pay signficantly over their financial weight, which can be financiall difficult and risky, considering buyers generally apply for mortgages from banks.
#
# #### Estimated Run Time: ~1 second

# %%
# %%sql
# SELECT
#     hst.region_name,
#     FORMAT(avg_sale_price_2020, 0) AS avg_sale_price_2020,
#     chi.medianHouseholdIncome AS median_household_income_2019,
#     CAST(
#         (avg_sale_price_2020 / chi.medianHouseholdIncome) AS decimal(12,2)
#     ) AS price_to_income_ratio,
#     CASE
#         WHEN (avg_sale_price_2020 / chi.medianHouseholdIncome) < 2.5 THEN 'Affordable'
#         WHEN (avg_sale_price_2020 / chi.medianHouseholdIncome) BETWEEN 2.5 AND 5.0 THEN 'Expensive'
#         WHEN (avg_sale_price_2020 / chi.medianHouseholdIncome) > 5.0 THEN 'Incredibly Expensive'
#     END AS property_affordability
# FROM home_sale_totals_2020 hst
# JOIN countyHouseholdIncome chi
#     ON hst.region_name LIKE chi.countyName
# ORDER BY price_to_income_ratio;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 165 rows affected.
# [('Allegany County, NY', '85,302', 49411, Decimal('1.73'), 'Affordable'),
#  ('Refugio County, TX', '86,500', 46883, Decimal('1.85'), 'Affordable'),
#  ('Fisher County, TX', '101,285', 51053, Decimal('1.98'), 'Affordable'),
#  ('Wyoming County, NY', '118,417', 58214, Decimal('2.03'), 'Affordable'),
#  ('Haskell County, TX', '78,892', 38613, Decimal('2.04'), 'Affordable'),
#  ('Oswego County, NY', '123,037', 57640, Decimal('2.13'), 'Affordable'),
#  ('Chautauqua County, NY', '107,117', 50143, Decimal('2.14'), 'Affordable'),
#  ('Throckmorton County, TX', '91,500', 42746, Decimal('2.14'), 'Affordable'),
#  ('Genesee County, NY', '134,758', 62570, Decimal('2.15'), 'Affordable'),
#  ('Orleans County, NY', '118,904', 53115, Decimal('2.24'), 'Affordable'),
#  ('Cayuga County, NY', '136,451', 58055, Decimal('2.35'), 'Affordable'),
#  ('Montgomery County, NY', '122,359', 52092, Decimal('2.35'), 'Affordable'),
#  ('Fulton County, NY', '117,922', 50061, Decimal('2.36'), 'Affordable'),
#  ('Wayne County, NY', '147,646', 61989, Decimal('2.38'), 'Affordable'),
#  ('Coleman County, TX', '109,782', 44834, Decimal('2.45'), 'Affordable'),
#  ('Cattaraugus County, NY', '124,781', 50783, Decimal('2.46'), 'Affordable'),
#  ('Livingston County, NY', '148,605', 60268, Decimal('2.47'), 'Affordable'),
#  ('Niagara County, NY', '139,899', 56371, Decimal('2.48'), 'Affordable'),
#  ('Karnes County, TX', '137,028', 54843, Decimal('2.50'), 'Affordable'),
#  ('Onondaga County, NY', '160,220', 61597, Decimal('2.60'), 'Expensive'),
#  ('Monroe County, NY', '164,699', 62159, Decimal('2.65'), 'Expensive'),
#  ('Schoharie County, NY', '158,650', 58927, Decimal('2.69'), 'Expensive'),
#  ('Jim Wells County, TX', '119,833', 44444, Decimal('2.70'), 'Expensive'),
#  ('Madison County, NY', '169,199', 61713, Decimal('2.74'), 'Expensive'),
#  ('Kleberg County, TX', '129,024', 47169, Decimal('2.74'), 'Expensive'),
#  ('Delta County, TX', '141,624', 51348, Decimal('2.76'), 'Expensive'),
#  ('Schenectady County, NY', '179,675', 64960, Decimal('2.77'), 'Expensive'),
#  ('Live Oak County, TX', '151,151', 54163, Decimal('2.79'), 'Expensive'),
#  ('Washington County, NY', '160,790', 56897, Decimal('2.83'), 'Expensive'),
#  ('Rensselaer County, NY', '202,502', 70688, Decimal('2.86'), 'Expensive'),
#  ('Fort Bend County, TX', '290,871', 101361, Decimal('2.87'), 'Expensive'),
#  ('Erie County, NY', '175,984', 60620, Decimal('2.90'), 'Expensive'),
#  ('Jones County, TX', '148,916', 51094, Decimal('2.91'), 'Expensive'),
#  ('Rockwall County, TX', '316,714', 105763, Decimal('2.99'), 'Expensive'),
#  ('Montague County, TX', '160,498', 53649, Decimal('2.99'), 'Expensive'),
#  ('Callahan County, TX', '154,684', 50812, Decimal('3.04'), 'Expensive'),
#  ('Chambers County, TX', '284,683', 93351, Decimal('3.05'), 'Expensive'),
#  ('Brazoria County, TX', '256,454', 83704, Decimal('3.06'), 'Expensive'),
#  ('Ontario County, NY', '205,267', 66754, Decimal('3.07'), 'Expensive'),
#  ('Montgomery County, TX', '279,088', 88833, Decimal('3.14'), 'Expensive'),
#  ('Brown County, TX', '177,129', 56040, Decimal('3.16'), 'Expensive'),
#  ('Comanche County, TX', '170,837', 54122, Decimal('3.16'), 'Expensive'),
#  ('Guadalupe County, TX', '249,561', 78801, Decimal('3.17'), 'Expensive'),
#  ('Young County, TX', '168,047', 52643, Decimal('3.19'), 'Expensive'),
#  ('Hill County, TX', '170,210', 53210, Decimal('3.20'), 'Expensive'),
#  ('Eastland County, TX', '150,256', 46991, Decimal('3.20'), 'Expensive'),
#  ('Stephens County, TX', '150,492', 46658, Decimal('3.23'), 'Expensive'),
#  ('Sullivan County, NY', '192,069', 58851, Decimal('3.26'), 'Expensive'),
#  ('DeWitt County, TX', '172,301', 52544, Decimal('3.28'), 'Expensive'),
#  ('Williamson County, TX', '305,632', 92661, Decimal('3.30'), 'Expensive'),
#  ('Kaufman County, TX', '247,344', 75009, Decimal('3.30'), 'Expensive'),
#  ('Albany County, NY', '229,710', 69408, Decimal('3.31'), 'Expensive'),
#  ('Fannin County, TX', '185,751', 56123, Decimal('3.31'), 'Expensive'),
#  ('Frio County, TX', '135,373', 40360, Decimal('3.35'), 'Expensive'),
#  ('Saratoga County, NY', '299,686', 89071, Decimal('3.36'), 'Expensive'),
#  ('Putnam County, NY', '357,339', 105600, Decimal('3.38'), 'Expensive'),
#  ('Victoria County, TX', '194,641', 57344, Decimal('3.39'), 'Expensive'),
#  ('Stonewall County, TX', '165,165', 48267, Decimal('3.42'), 'Expensive'),
#  ('Orange County, NY', '290,284', 83188, Decimal('3.49'), 'Expensive'),
#  ('Grayson County, TX', '201,357', 57439, Decimal('3.51'), 'Expensive'),
#  ('Taylor County, TX', '192,191', 54465, Decimal('3.53'), 'Expensive'),
#  ('Bell County, TX', '194,049', 54831, Decimal('3.54'), 'Expensive'),
#  ('Hood County, TX', '265,331', 74534, Decimal('3.56'), 'Expensive'),
#  ('Navarro County, TX', '173,178', 48649, Decimal('3.56'), 'Expensive'),
#  ('Hunt County, TX', '205,761', 57513, Decimal('3.58'), 'Expensive'),
#  ('Denton County, TX', '328,378', 90910, Decimal('3.61'), 'Expensive'),
#  ('El Paso County, TX', '175,591', 48629, Decimal('3.61'), 'Expensive'),
#  ('Galveston County, TX', '264,835', 73214, Decimal('3.62'), 'Expensive'),
#  ('Tarrant County, TX', '256,048', 70130, Decimal('3.65'), 'Expensive'),
#  ('Warren County, NY', '230,593', 63240, Decimal('3.65'), 'Expensive'),
#  ('Collin County, TX', '354,876', 96847, Decimal('3.66'), 'Expensive'),
#  ('Ellis County, TX', '288,648', 78341, Decimal('3.68'), 'Expensive'),
#  ('Johnson County, TX', '244,536', 66538, Decimal('3.68'), 'Expensive'),
#  ('Liberty County, TX', '196,865', 53274, Decimal('3.70'), 'Expensive'),
#  ('Wharton County, TX', '186,442', 49901, Decimal('3.74'), 'Expensive'),
#  ('Comal County, TX', '329,951', 87976, Decimal('3.75'), 'Expensive'),
#  ('Hopkins County, TX', '190,605', 50332, Decimal('3.79'), 'Expensive'),
#  ('Starr County, TX', '123,339', 32516, Decimal('3.79'), 'Expensive'),
#  ('Wise County, TX', '267,651', 70468, Decimal('3.80'), 'Expensive'),
#  ('Jack County, TX', '211,388', 55358, Decimal('3.82'), 'Expensive'),
#  ('Cooke County, TX', '235,504', 61186, Decimal('3.85'), 'Expensive'),
#  ('Dutchess County, NY', '327,852', 84564, Decimal('3.88'), 'Expensive'),
#  ('Atascosa County, TX', '223,985', 57309, Decimal('3.91'), 'Expensive'),
#  ('Parker County, TX', '324,365', 82501, Decimal('3.93'), 'Expensive'),
#  ('Harris County, TX', '243,276', 61638, Decimal('3.95'), 'Expensive'),
#  ('Bexar County, TX', '235,014', 58956, Decimal('3.99'), 'Expensive'),
#  ('Shackelford County, TX', '259,775', 65095, Decimal('3.99'), 'Expensive'),
#  ('Erath County, TX', '213,846', 53044, Decimal('4.03'), 'Expensive'),
#  ('Caldwell County, TX', '224,693', 55301, Decimal('4.06'), 'Expensive'),
#  ('Hays County, TX', '297,612', 72890, Decimal('4.08'), 'Expensive'),
#  ('Lee County, TX', '243,643', 59250, Decimal('4.11'), 'Expensive'),
#  ('Hidalgo County, TX', '172,662', 41656, Decimal('4.14'), 'Expensive'),
#  ('Suffolk County, NY', '438,363', 105241, Decimal('4.17'), 'Expensive'),
#  ('Lavaca County, TX', '219,224', 52632, Decimal('4.17'), 'Expensive'),
#  ('Nueces County, TX', '237,650', 56079, Decimal('4.24'), 'Expensive'),
#  ('Somervell County, TX', '291,480', 67897, Decimal('4.29'), 'Expensive'),
#  ('Bastrop County, TX', '270,023', 62627, Decimal('4.31'), 'Expensive'),
#  ('Dallas County, TX', '271,098', 61807, Decimal('4.39'), 'Expensive'),
#  ('Wilson County, TX', '346,203', 76905, Decimal('4.50'), 'Expensive'),
#  ('Rockland County, NY', '455,117', 99831, Decimal('4.56'), 'Expensive'),
#  ('Kendall County, TX', '433,842', 94899, Decimal('4.57'), 'Expensive'),
#  ('Houston County, TX', '199,798', 43601, Decimal('4.58'), 'Expensive'),
#  ('Bandera County, TX', '274,050', 59604, Decimal('4.60'), 'Expensive'),
#  ('Colorado County, TX', '259,359', 55607, Decimal('4.66'), 'Expensive'),
#  ('Hudspeth County, TX', '185,026', 39309, Decimal('4.71'), 'Expensive'),
#  ('Walker County, TX', '224,593', 47519, Decimal('4.73'), 'Expensive'),
#  ('Austin County, TX', '324,558', 68311, Decimal('4.75'), 'Expensive'),
#  ('Nassau County, NY', '568,544', 117767, Decimal('4.83'), 'Expensive'),
#  ('Mills County, TX', '226,240', 46876, Decimal('4.83'), 'Expensive'),
#  ('Waller County, TX', '299,931', 61822, Decimal('4.85'), 'Expensive'),
#  ('San Patricio County, TX', '277,768', 57302, Decimal('4.85'), 'Expensive'),
#  ('Gonzales County, TX', '236,599', 48425, Decimal('4.89'), 'Expensive'),
#  ('Medina County, TX', '297,839', 60695, Decimal('4.91'), 'Expensive'),
#  ('Hamilton County, TX', '262,510', 52505, Decimal('5.00'), 'Expensive'),
#  ('Kern County, CA', '266,680', 53245, Decimal('5.01'), 'Incredibly Expensive'),
#  ('Travis County, TX', '405,923', 80690, Decimal('5.03'), 'Incredibly Expensive'),
#  ('Washington County, TX', '298,027', 59039, Decimal('5.05'), 'Incredibly Expensive'),
#  ('Henderson County, TX', '252,311', 49896, Decimal('5.06'), 'Incredibly Expensive'),
#  ('Madera County, CA', '314,807', 61105, Decimal('5.15'), 'Incredibly Expensive'),
#  ('Palo Pinto County, TX', '258,372', 50159, Decimal('5.15'), 'Incredibly Expensive'),
#  ('Merced County, CA', '308,496', 59733, Decimal('5.16'), 'Incredibly Expensive'),
#  ('Nolan County, TX', '239,200', 46389, Decimal('5.16'), 'Incredibly Expensive'),
#  ('Goliad County, TX', '293,631', 56758, Decimal('5.17'), 'Incredibly Expensive'),
#  ('Calaveras County, CA', '353,304', 68248, Decimal('5.18'), 'Incredibly Expensive'),
#  ('San Jacinto County, TX', '222,400', 42633, Decimal('5.22'), 'Incredibly Expensive'),
#  ('Fresno County, CA', '304,263', 56926, Decimal('5.34'), 'Incredibly Expensive'),
#  ('Glenn County, CA', '300,298', 55682, Decimal('5.39'), 'Incredibly Expensive'),
#  ('Placer County, CA', '530,966', 97688, Decimal('5.44'), 'Incredibly Expensive'),
#  ('Aransas County, TX', '293,999', 53085, Decimal('5.54'), 'Incredibly Expensive'),
#  ('Solano County, CA', '476,740', 85704, Decimal('5.56'), 'Incredibly Expensive'),
#  ('Sacramento County, CA', '406,514', 71891, Decimal('5.65'), 'Incredibly Expensive'),
#  ('Stanislaus County, CA', '357,051', 62761, Decimal('5.69'), 'Incredibly Expensive'),
#  ('Amador County, CA', '360,331', 62640, Decimal('5.75'), 'Incredibly Expensive'),
#  ('San Bernardino County, CA', '390,848', 67398, Decimal('5.80'), 'Incredibly Expensive'),
#  ('Westchester County, NY', '596,896', 101741, Decimal('5.87'), 'Incredibly Expensive'),
#  ('Riverside County, CA', '428,552', 72905, Decimal('5.88'), 'Incredibly Expensive'),
#  ('San Joaquin County, CA', '409,809', 68458, Decimal('5.99'), 'Incredibly Expensive'),
#  ('El Dorado County, CA', '521,986', 86202, Decimal('6.06'), 'Incredibly Expensive'),
#  ('Burnet County, TX', '383,012', 62827, Decimal('6.10'), 'Incredibly Expensive'),
#  ('Butte County, CA', '364,047', 58394, Decimal('6.23'), 'Incredibly Expensive'),
#  ('Lake County, CA', '294,701', 46897, Decimal('6.28'), 'Incredibly Expensive'),
#  ('Fayette County, TX', '393,549', 62195, Decimal('6.33'), 'Incredibly Expensive'),
#  ('Contra Costa County, CA', '680,934', 106555, Decimal('6.39'), 'Incredibly Expensive'),
#  ('Richmond County, NY', '565,161', 86624, Decimal('6.52'), 'Incredibly Expensive'),
#  ('Yolo County, CA', '473,691', 70951, Decimal('6.68'), 'Incredibly Expensive'),
#  ('Ventura County, CA', '655,988', 91446, Decimal('7.17'), 'Incredibly Expensive'),
#  ('Nevada County, CA', '520,130', 69550, Decimal('7.48'), 'Incredibly Expensive'),
#  ('San Benito County, CA', '631,605', 84209, Decimal('7.50'), 'Incredibly Expensive'),
#  ('San Diego County, CA', '630,033', 83576, Decimal('7.54'), 'Incredibly Expensive'),
#  ('Sonoma County, CA', '660,543', 87084, Decimal('7.59'), 'Incredibly Expensive'),
#  ('Orange County, CA', '769,705', 95761, Decimal('8.04'), 'Incredibly Expensive'),
#  ('Napa County, CA', '735,856', 90230, Decimal('8.16'), 'Incredibly Expensive'),
#  ('Alameda County, CA', '881,938', 107589, Decimal('8.20'), 'Incredibly Expensive'),
#  ('San Luis Obispo County, CA', '643,146', 76599, Decimal('8.40'), 'Incredibly Expensive'),
#  ('Queens County, NY', '627,802', 72975, Decimal('8.60'), 'Incredibly Expensive'),
#  ('Monterey County, CA', '693,092', 76509, Decimal('9.06'), 'Incredibly Expensive'),
#  ('Santa Clara County, CA', '1,205,308', 132444, Decimal('9.10'), 'Incredibly Expensive'),
#  ('Los Angeles County, CA', '684,578', 72721, Decimal('9.41'), 'Incredibly Expensive'),
#  ('Santa Barbara County, CA', '713,698', 74530, Decimal('9.58'), 'Incredibly Expensive'),
#  ('Santa Cruz County, CA', '890,298', 85770, Decimal('10.38'), 'Incredibly Expensive'),
#  ('San Mateo County, CA', '1,446,796', 135234, Decimal('10.70'), 'Incredibly Expensive'),
#  ('Marin County, CA', '1,275,437', 112069, Decimal('11.38'), 'Incredibly Expensive'),
#  ('Bronx County, NY', '515,260', 41470, Decimal('12.42'), 'Incredibly Expensive'),
#  ('New York County, NY', '1,163,702', 93007, Decimal('12.51'), 'Incredibly Expensive'),
#  ('Kings County, NY', '861,830', 66501, Decimal('12.96'), 'Incredibly Expensive')]

# %% [markdown]
# #### Recommendation:
# For this query, I have collected the following data for county/metro regions for the year 2020:
# - region name
# - 2020 average median sale price
# - 2019 median household income
# - price to income ratio
# - property affordability rating
#
# Based on the above results, I believe that Redfin should expand their offerings to buyers by providing information and guidance on how to apply for loans/mortgages for buyers searching in markets where the price to income ratio is far above what is considered affordable. By doing so, Redfin buyers will trust the site more to guide their house buying decision since Redfin actively provides different options on their website catered towards the individual financing needs of each customer.

# %% [markdown]
# ### Primary Question
# #### Based on housing data collected between 2017 and 2020, how have the housing markets in county/metro regions in California, New York, and Texas performed and which regions provide the best potential investments for residential property buyers?
#
# #### Business Justification:
# As an analyst at Redfin, it is important to understand where home buyers have the greatest opportunities in terms of finding ample, healthy and potentially lucrative home investments in the long-term. By analyzing the housing market the perspective of a buyer, Redfin analysts can optimally adjust their listings and the geographic regions in which they service by either increasing their marketing to those regions or investing more in outreach to local real estate agencies. Similarly, by providing reliable data insights about the financial health of a property investment as well as its financial consequences, good or bad, Redfin can boost their trusting relationships with consumers so that buyers will be more inclined to use Redfin's service and buy through the site, thereby increasing revenues all around.
#
# #### Estimated Run Time: ~1m 9s

# %%
# %%sql
# WITH cte_yoy_sales_data AS (
#     SELECT
#         DISTINCT(hd.region_name),
#         (
#             (
#                 (hst2.home_sale_year_total_2018 / hst.home_sale_year_total_2017) +
#                 (hst3.home_sale_year_total_2019 / hst2.home_sale_year_total_2018) +
#                 (hst4.home_sale_year_total_2020 / hst3.home_sale_year_total_2019)
#             ) / 3
#         ) AS avg_yoy_sales_change
#     FROM housing_data hd
#     JOIN home_sale_totals_2017 hst
#         ON hd.region_name = hst.region_name
#     JOIN home_sale_totals_2018 hst2
#         ON hd.region_name = hst2.region_name
#     JOIN home_sale_totals_2019 hst3
#         ON hd.region_name = hst3.region_name
#     JOIN home_sale_totals_2020 hst4
#         ON hd.region_name = hst4.region_name
#     WHERE hst.home_sale_year_total_2017 > 1000
#     ORDER BY avg_yoy_sales_change DESC
# )
# SELECT
#     hd.region_name,
#     AVG(median_sale_price) OVER(PARTITION BY region_name) AS avg_median_sale_price,
#     chi.medianHouseholdIncome AS median_household_income,
#     CAST(
#         ( AVG(median_sale_price) OVER(PARTITION BY region_name)/ chi.medianHouseholdIncome) AS decimal(12,2)
#     ) AS price_to_income_ratio,
#     CASE
#         WHEN
#             CAST(
#             ( AVG(median_sale_price) OVER(PARTITION BY region_name)/ chi.medianHouseholdIncome) AS decimal(12,2)
#             ) < 2.5
#             AND CAST(cte.avg_yoy_sales_change AS decimal (12,2)) > 1
#             AND CAST(yspc.yoy_sale_price_change AS decimal (12,2)) > 1
#         THEN 'Ideal to buy'
#         WHEN
#             CAST(
#             ( AVG(median_sale_price) OVER(PARTITION BY region_name)/ chi.medianHouseholdIncome) AS decimal(12,2)
#             ) BETWEEN 2.5 AND 5
#             AND CAST(cte.avg_yoy_sales_change AS decimal (12,2)) > 1
#             AND CAST(yspc.yoy_sale_price_change AS decimal (12,2)) > 1
#         THEN 'Moderate risk; good future gains'
#         WHEN
#             CAST(
#             ( AVG(median_sale_price) OVER(PARTITION BY region_name)/ chi.medianHouseholdIncome) AS decimal(12,2)
#             ) > 5
#             AND CAST(cte.avg_yoy_sales_change AS decimal (12,2)) > 1
#             AND CAST(yspc.yoy_sale_price_change AS decimal (12,2)) > 1
#         THEN 'high risk; potential future gains'
#         WHEN
#             CAST(
#             ( AVG(median_sale_price) OVER(PARTITION BY region_name)/ chi.medianHouseholdIncome) AS decimal(12,2)
#             ) > 5
#             AND CAST(cte.avg_yoy_sales_change AS decimal (12,2)) < 1
#                 OR CAST(yspc.yoy_sale_price_change AS decimal (12,2)) < 1
#         THEN 'Extreme risk; not recommended'
#         WHEN
#             CAST(
#             ( AVG(median_sale_price) OVER(PARTITION BY region_name)/ chi.medianHouseholdIncome) AS decimal(12,2)
#             ) < 2.5
#             AND (CAST(cte.avg_yoy_sales_change AS decimal (12,2)) < 1
#                 AND CAST(yspc.yoy_sale_price_change AS decimal (12,2)) > 1)
#             OR (CAST(cte.avg_yoy_sales_change AS decimal (12,2)) > 1
#                 AND CAST(yspc.yoy_sale_price_change AS decimal (12,2)) < 1)
#         THEN 'Little risk; good buy'
#         ELSE 'Meh; not recommended'
#     END AS homebuying_rating,
#     CAST(cte.avg_yoy_sales_change AS decimal (12,2)) AS avg_home_sales_change_yoy,
#     CAST(yspc.yoy_sale_price_change AS decimal (12,2)) AS avg_sale_price_change_yoy
# FROM housing_data hd
# JOIN yoy_sales_price_change yspc
#     ON hd.region_name = yspc.region_name
# JOIN cte_yoy_sales_data cte
# ON hd.region_name = cte.region_name
# JOIN countyHouseholdIncome chi
#     ON hd.region_name LIKE chi.countyName
# GROUP BY region_name
# ORDER BY
#     price_to_income_ratio, avg_home_sales_change_yoy DESC,
#     avg_sale_price_change_yoy DESC;
# Out:
#  * mysql://admin:***@sql-project.ckos5u2mpfmb.us-east-1.rds.amazonaws.com/sql_project
# 82 rows affected.
# [('Chautauqua County, NY', 80900.0, 50143, Decimal('1.61'), 'Ideal to buy', Decimal('1.06'), Decimal('1.10')),
#  ('Oswego County, NY', 104500.0, 57640, Decimal('1.81'), 'Little risk; good buy', Decimal('0.98'), Decimal('1.08')),
#  ('Niagara County, NY', 104950.0, 56371, Decimal('1.86'), 'Little risk; good buy', Decimal('0.99'), Decimal('1.08')),
#  ('Monroe County, NY', 125000.0, 62159, Decimal('2.01'), 'Little risk; good buy', Decimal('0.98'), Decimal('1.07')),
#  ('Wayne County, NY', 140000.0, 61989, Decimal('2.26'), 'Little risk; good buy', Decimal('0.97'), Decimal('1.07')),
#  ('Rensselaer County, NY', 163187.9, 70688, Decimal('2.31'), 'Ideal to buy', Decimal('1.01'), Decimal('1.07')),
#  ('Onondaga County, NY', 146500.0, 61597, Decimal('2.38'), 'Little risk; good buy', Decimal('0.96'), Decimal('1.06')),
#  ('Ontario County, NY', 168862.5, 66754, Decimal('2.53'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.08')),
#  ('Rockwall County, TX', 285950.0, 105763, Decimal('2.70'), 'Moderate risk; good future gains', Decimal('1.08'), Decimal('1.04')),
#  ('Erie County, NY', 166000.0, 60620, Decimal('2.74'), 'Meh; not recommended', Decimal('0.98'), Decimal('1.08')),
#  ('Taylor County, TX', 156075.0, 54465, Decimal('2.87'), 'Moderate risk; good future gains', Decimal('1.05'), Decimal('1.06')),
#  ('Brazoria County, TX', 244960.0, 83704, Decimal('2.93'), 'Moderate risk; good future gains', Decimal('1.09'), Decimal('1.03')),
#  ('Dutchess County, NY', 248250.0, 84564, Decimal('2.94'), 'Moderate risk; good future gains', Decimal('1.09'), Decimal('1.07')),
#  ('Williamson County, TX', 274412.5, 92661, Decimal('2.96'), 'Moderate risk; good future gains', Decimal('1.07'), Decimal('1.04')),
#  ('Schenectady County, NY', 192500.0, 64960, Decimal('2.96'), 'Moderate risk; good future gains', Decimal('1.01'), Decimal('1.07')),
#  ('Montgomery County, TX', 265000.0, 88833, Decimal('2.98'), 'Moderate risk; good future gains', Decimal('1.09'), Decimal('1.04')),
#  ('Orange County, NY', 248000.0, 83188, Decimal('2.98'), 'Moderate risk; good future gains', Decimal('1.01'), Decimal('1.09')),
#  ('Fort Bend County, TX', 304995.0, 101361, Decimal('3.01'), 'Moderate risk; good future gains', Decimal('1.08'), Decimal('1.02')),
#  ('Saratoga County, NY', 270100.0, 89071, Decimal('3.03'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.04')),
#  ('Albany County, NY', 213270.8, 69408, Decimal('3.07'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.04')),
#  ('El Paso County, TX', 149950.0, 48629, Decimal('3.08'), 'Moderate risk; good future gains', Decimal('1.11'), Decimal('1.06')),
#  ('Guadalupe County, TX', 243450.0, 78801, Decimal('3.09'), 'Moderate risk; good future gains', Decimal('1.06'), Decimal('1.04')),
#  ('Collin County, TX', 303000.0, 96847, Decimal('3.13'), 'Moderate risk; good future gains', Decimal('1.04'), Decimal('1.03')),
#  ('Hood County, TX', 235112.5, 74534, Decimal('3.15'), 'Moderate risk; good future gains', Decimal('1.03'), Decimal('1.06')),
#  ('Galveston County, TX', 235000.0, 73214, Decimal('3.21'), 'Moderate risk; good future gains', Decimal('1.06'), Decimal('1.05')),
#  ('Grayson County, TX', 184900.0, 57439, Decimal('3.22'), 'Moderate risk; good future gains', Decimal('1.07'), Decimal('1.08')),
#  ('Putnam County, NY', 342000.0, 105600, Decimal('3.24'), 'Moderate risk; good future gains', Decimal('1.06'), Decimal('1.04')),
#  ('Bell County, TX', 178000.0, 54831, Decimal('3.25'), 'Moderate risk; good future gains', Decimal('1.08'), Decimal('1.08')),
#  ('Kaufman County, TX', 252325.4, 75009, Decimal('3.36'), 'Moderate risk; good future gains', Decimal('1.13'), Decimal('1.05')),
#  ('Wise County, TX', 238979.1, 70468, Decimal('3.39'), 'Moderate risk; good future gains', Decimal('1.06'), Decimal('1.07')),
#  ('Tarrant County, TX', 244700.0, 70130, Decimal('3.49'), 'Moderate risk; good future gains', Decimal('1.01'), Decimal('1.06')),
#  ('Harris County, TX', 220000.0, 61638, Decimal('3.57'), 'Moderate risk; good future gains', Decimal('1.04'), Decimal('1.05')),
#  ('Parker County, TX', 305500.0, 82501, Decimal('3.70'), 'Moderate risk; good future gains', Decimal('1.06'), Decimal('1.07')),
#  ('Denton County, TX', 339231.1, 90910, Decimal('3.73'), 'Moderate risk; good future gains', Decimal('1.05'), Decimal('1.04')),
#  ('Hunt County, TX', 217462.5, 57513, Decimal('3.78'), 'Moderate risk; good future gains', Decimal('1.11'), Decimal('1.07')),
#  ('Merced County, CA', 225500.0, 59733, Decimal('3.78'), 'Moderate risk; good future gains', Decimal('1.02'), Decimal('1.08')),
#  ('Ellis County, TX', 298629.9, 78341, Decimal('3.81'), 'Moderate risk; good future gains', Decimal('1.09'), Decimal('1.07')),
#  ('Kern County, CA', 208000.0, 53245, Decimal('3.91'), 'Moderate risk; good future gains', Decimal('1.01'), Decimal('1.07')),
#  ('Dallas County, TX', 247000.0, 61807, Decimal('4.00'), 'Moderate risk; good future gains', Decimal('1.01'), Decimal('1.06')),
#  ('Hays County, TX', 294862.5, 72890, Decimal('4.05'), 'Moderate risk; good future gains', Decimal('1.12'), Decimal('1.05')),
#  ('Comal County, TX', 357500.0, 87976, Decimal('4.06'), 'Moderate risk; good future gains', Decimal('1.16'), Decimal('1.04')),
#  ('Hidalgo County, TX', 170000.0, 41656, Decimal('4.08'), 'Moderate risk; good future gains', Decimal('1.09'), Decimal('1.06')),
#  ('Madera County, CA', 251250.0, 61105, Decimal('4.11'), 'Moderate risk; good future gains', Decimal('1.04'), Decimal('1.09')),
#  ('Bexar County, TX', 245000.0, 58956, Decimal('4.16'), 'Moderate risk; good future gains', Decimal('1.05'), Decimal('1.06')),
#  ('Travis County, TX', 335750.0, 80690, Decimal('4.16'), 'Moderate risk; good future gains', Decimal('1.04'), Decimal('1.07')),
#  ('Johnson County, TX', 288950.0, 66538, Decimal('4.34'), 'Moderate risk; good future gains', Decimal('1.10'), Decimal('1.07')),
#  ('Butte County, CA', 258000.0, 58394, Decimal('4.42'), 'Meh; not recommended', Decimal('0.96'), Decimal('1.09')),
#  ('Suffolk County, NY', 473500.0, 105241, Decimal('4.50'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.08')),
#  ('Westchester County, NY', 463900.0, 101741, Decimal('4.56'), 'Meh; not recommended', Decimal('0.99'), Decimal('1.07')),
#  ('Rockland County, NY', 462500.0, 99831, Decimal('4.63'), 'Moderate risk; good future gains', Decimal('1.02'), Decimal('1.05')),
#  ('Solano County, CA', 397500.0, 85704, Decimal('4.64'), 'Meh; not recommended', Decimal('0.98'), Decimal('1.06')),
#  ('Nassau County, NY', 560000.0, 117767, Decimal('4.76'), 'Meh; not recommended', Decimal('0.98'), Decimal('1.05')),
#  ('Placer County, CA', 466000.0, 97688, Decimal('4.77'), 'Moderate risk; good future gains', Decimal('1.02'), Decimal('1.06')),
#  ('Stanislaus County, CA', 300000.0, 62761, Decimal('4.78'), 'Meh; not recommended', Decimal('0.96'), Decimal('1.08')),
#  ('San Bernardino County, CA', 340000.0, 67398, Decimal('5.04'), 'Extreme risk; not recommended', Decimal('0.97'), Decimal('1.07')),
#  ('Sacramento County, CA', 364000.0, 71891, Decimal('5.06'), 'Extreme risk; not recommended', Decimal('0.97'), Decimal('1.08')),
#  ('El Dorado County, CA', 438000.0, 86202, Decimal('5.08'), 'high risk; potential future gains', Decimal('1.08'), Decimal('1.05')),
#  ('Riverside County, CA', 375000.0, 72905, Decimal('5.14'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.07')),
#  ('Fresno County, CA', 332117.0, 56926, Decimal('5.83'), 'Extreme risk; not recommended', Decimal('0.97'), Decimal('1.07')),
#  ('Yolo County, CA', 432500.0, 70951, Decimal('6.10'), 'Extreme risk; not recommended', Decimal('0.97'), Decimal('1.05')),
#  ('Nevada County, CA', 425000.0, 69550, Decimal('6.11'), 'high risk; potential future gains', Decimal('1.06'), Decimal('1.06')),
#  ('Ventura County, CA', 579000.0, 91446, Decimal('6.33'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.05')),
#  ('Richmond County, NY', 550000.0, 86624, Decimal('6.35'), 'Extreme risk; not recommended', Decimal('0.94'), Decimal('1.04')),
#  ('San Joaquin County, CA', 438000.0, 68458, Decimal('6.40'), 'Extreme risk; not recommended', Decimal('0.97'), Decimal('1.08')),
#  ('Contra Costa County, CA', 730000.0, 106555, Decimal('6.85'), 'Extreme risk; not recommended', Decimal('0.99'), Decimal('1.06')),
#  ('Sonoma County, CA', 617000.0, 87084, Decimal('7.09'), 'high risk; potential future gains', Decimal('1.01'), Decimal('1.04')),
#  ('San Diego County, CA', 621500.0, 83576, Decimal('7.44'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.06')),
#  ('Orange County, CA', 725000.0, 95761, Decimal('7.57'), 'Extreme risk; not recommended', Decimal('0.98'), Decimal('1.05')),
#  ('Alameda County, CA', 820000.0, 107589, Decimal('7.62'), 'Extreme risk; not recommended', Decimal('0.97'), Decimal('1.05')),
#  ('San Luis Obispo County, CA', 619450.0, 76599, Decimal('8.09'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.05')),
#  ('Monterey County, CA', 630000.0, 76509, Decimal('8.23'), 'Meh; not recommended', Decimal('1.00'), Decimal('1.08')),
#  ('Napa County, CA', 750000.0, 90230, Decimal('8.31'), 'high risk; potential future gains', Decimal('1.01'), Decimal('1.04')),
#  ('Los Angeles County, CA', 630000.0, 72721, Decimal('8.66'), 'Extreme risk; not recommended', Decimal('0.95'), Decimal('1.06')),
#  ('Santa Clara County, CA', 1189000.0, 132444, Decimal('8.98'), 'Extreme risk; not recommended', Decimal('0.95'), Decimal('1.06')),
#  ('Marin County, CA', 1008550.0, 112069, Decimal('9.00'), 'high risk; potential future gains', Decimal('1.02'), Decimal('1.06')),
#  ('Queens County, NY', 675000.0, 72975, Decimal('9.25'), 'Extreme risk; not recommended', Decimal('0.92'), Decimal('1.06')),
#  ('Santa Cruz County, CA', 817500.0, 85770, Decimal('9.53'), 'Extreme risk; not recommended', Decimal('0.98'), Decimal('1.05')),
#  ('Santa Barbara County, CA', 767500.0, 74530, Decimal('10.30'), 'high risk; potential future gains', Decimal('1.01'), Decimal('1.07')),
#  ('San Mateo County, CA', 1425000.0, 135234, Decimal('10.54'), 'Extreme risk; not recommended', Decimal('0.98'), Decimal('1.06')),
#  ('Bronx County, NY', 472500.0, 41470, Decimal('11.39'), 'Extreme risk; not recommended', Decimal('0.91'), Decimal('1.08')),
#  ('Kings County, NY', 872935.0, 66501, Decimal('13.13'), 'Extreme risk; not recommended', Decimal('0.93'), Decimal('1.01')),
#  ('New York County, NY', 1230000.0, 93007, Decimal('13.22'), 'Extreme risk; not recommended', Decimal('0.87'), Decimal('0.97'))]

# %% [markdown]
# #### Recommendation:
# In the above query, I have collected a wide variety of useful measurements with the goal of determining a "Redfin rating" of sorts, similar to what you would find when researching stocks and seeing the analyst's ratings. For each CA, NY, or TX county with over 1000 new listings in 2017, I have collected the following over the course of the 2017-2020 period:
# - average median sale price
# - 2019 median household income
# - home price-to-income ratio
# - Redfin homebuy rating
# - average year-over-year change in total home sales
# - average year-over-year change in median home sale prices
#
# Based on the results, I recommend that Redfin implement a similar feature to rank different counties and metro regions in terms of how optimal they are as financially safe investments for buyers. By taking into account multiple factors such as the price-to-income ratio and year-over-year sale price changes, Redfin can provide honest, statistically sound recommendations to buyers about how risky such an investment would be.
